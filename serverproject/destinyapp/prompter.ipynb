# %% [markdown]
# # TOC at E-M
#
# ## This is the master prompt engineering notebook for DestinyRecaps

# %%
# DIRECTORY SET
import os
import sys
from pathlib import Path
base_dir=Path(os.getcwd()).parent
os.chdir(base_dir)

import yaml
# data path
prompt_yaml_path="destinyapp/prompter_.yaml"

# %%
# DJANGO SETUP
import django
sys.path.append(os.path.abspath(''))
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "serverproject.settings")
django.setup()

# Import custom modules
from destinyapp import views
from destinyapp.models import TranscriptData
from destinyapp.api import ServerAiFunctions as saf

# Import async modules
import asyncio
from asgiref.sync import sync_to_async

# Import display modules
from IPython.display import display, Markdown

# Import other modules
import faiss

# import reloading
from importlib import reload
# Out:
# Keys loaded

# %% [markdown]
# # Useful reusables

# %%
del sys.modules['destinyapp.api.ServerAiFunctions']
import destinyapp.api.ServerAiFunctions as saf
reload(saf)

async def run_systems(system_functions, input_contexts):
    async def run_system(system_function):
        tasks=[]
        for input_context in input_contexts:
            task=system_function(**input_context)
            tasks.append(task)

        responses=await asyncio.gather(*tasks)
        return responses

    systems=[]
    for system_function in system_functions:
        system=run_system(system_function)
        systems.append(system)
    
    system_responses=await asyncio.gather(*systems)

    return system_responses

# save to prompt yaml
def save_to_prompt_yaml(input_prompt_data):
    with open(prompt_yaml_path, 'r') as file:
        prompt_data=yaml.load(file, Loader=yaml.FullLoader)
    prompt_data["working"]=input_prompt_data
    with open(prompt_yaml_path, 'w') as file:
        yaml.dump(prompt_data, file)

# %% [markdown]
# # TOC id=E-M
# ### Items
# - Summary Chunks id=9xq
# - Recap id=7l.
#     - Discord
#     - Website
# - Hook id=1m3
# - Chat v1@

# %% [markdown]
# # Summary Chunks 9xq

# %%
# TBD

# %% [markdown]
# # Recap 71.

# %%
# production test
discord_recaps_to_send=[{"meta":"Test","yt_id":"3kJr7ODrwNw"}]
trancript_model_data=await saf.grab_transcript_data(discord_recaps_to_send[0]["yt_id"])
recap = await saf.meta_summary_generator.generate_meta_summary(trancript_model_data.summarized_chunks)

# %%
# Reset saf 
del sys.modules['destinyapp.api.ServerAiFunctions']
import destinyapp.api.ServerAiFunctions as saf
reload(saf)

# %%
# load transcript data for a video id

video_ids=["3kJr7ODrwNw"]

for video_id in video_ids:
    trancript_model_data=await saf.grab_transcript_data(video_id)
    saf.meta_summary_geneator.generate_meta_summary
    recap=await saf.generate_meta_summary(trancript_model_data.summarized_chunks, video_id)

    save_to_prompt_yaml({"recap":recap})

# %%
recap = await saf.meta_summary_geneator.generate_meta_summary(trancript_model_data.summarized_chunks)

# %%
discord_recaps_to_send=[{"meta":"Test","yt_id":"3kJr7ODrwNw"}]
print("Getting data")
trancript_model_data=await saf.grab_transcript_data(discord_recaps_to_send[0]["yt_id"])

# %%
video_ids=["3kJr7ODrwNw"]
all_transcript_model_data=[]
for video_id in video_ids:
    trancript_model_data=await saf.grab_transcript_data(video_id)
    all_transcript_model_data.append(trancript_model_data)

systems=[saf.meta_summary_geneator.generate_meta_summary]

# set config parameters
config_parameters=[
    {"model_company": saf.ModelCompanyEnum.anthropic, "model_name": saf.ModelNameEnum.claude_3_5_sonnet, "meta_model_prompt": saf.meta_summary_geneator.html_sytem},
    {"model_company": saf.ModelCompanyEnum.openai, "model_name": saf.ModelNameEnum.gpt_4o, "meta_model_prompt": saf.meta_summary_geneator.html_sytem},
]
# set inputs
input_variants=[
    {"summarized_chunks": trancript_model_data.summarized_chunks}
]

# set input contexts
input_contexts=[]
for input_variant in input_variants:
    for config_parameter in config_parameters:
        input_contexts.append({**config_parameter, **input_variant})

# run systems
system_responses=await run_systems(systems, input_contexts)

# save to prompt yaml
save_to_prompt_yaml(system_responses)

# %%
system_responses[0][0]

# %% [markdown]
# # Zoom in tags

# %%
trancript_model_data=await saf.grab_transcript_data(video_id)

# %%
trancript_model_data.summarized_chunks

# %%
recap="""Here's a comprehensive summary of the topics discussed in the collection of
summaries, organized into main topics and smaller details:

# Main Topics

### 1\. Content Creation and Streaming

  * **Twitch and streaming:** Destiny expresses frustration with Twitch, criticizing the current state of political content on the platform
  * **Relationships with other streamers:** Mentions being on good terms with several Twitch streamers
  * **Kit (streaming platform):** Discusses Kit's potential to compete with Twitch
  * **Collaboration with other creators:** Expresses reluctance due to differences in approach and audience expectations

### 2\. Political Commentary and Debates

  * **Criticism of political commentators:** Particularly those who made incorrect predictions about COVID-19
  * **Discussion of political extremes:** Potential for extremes to work together, drawing parallels to historical events
  * **Science and politics:** Criticizes misrepresentation of scientific facts for political purposes
  * **Israel-Palestine conflict:** References to debates and discussions on this topic

### 3\. Technical Issues and Discussions

  * **Video file management:** Issues with large video files and potential solutions
  * **Russian bot operation analysis:** In-depth discussion of a potential Russian bot operation on Twitter, focusing on error messages and technical aspects

### 4\. Personal Life and Relationships

  * **Work-life balance:** Discusses the relationship between career success and personal life
  * **Relationship discussions:** Comments on breakups and relationship dynamics

# Smaller Details and Brief Mentions

  * Upcoming events and travel plans
  * Typing speed and tests
  * Current events (e.g., protest group damaging Stonehenge)
  * Personal stance on issues and desire for fair treatment in online discourse
  * Mental state and need for emotional organization
  * Brief mentions of historical atrocities (Holocaust, Holodomor, Great Leap Forward)
  * Music and cultural gatekeeping
  * January 6th event
  * Merchandise promotion
  * YouTube drama
  * News story about a 12-year-old Jewish girl in Paris
  * Cocaine-related incident involving a 9-year-old
  * Qatar's relationship with Hamas and Al Jazeera
  * Douglas Murray's comments on Israel-Hamas conflict
  * Age of consent laws and pedophilia (mentioned in confusion)
  * Illegal firearm modifications

Overall, Destiny's tone throughout these discussions is often critical,
skeptical, and analytical. He frequently expresses frustration with
misinformation, personal attacks, and what he perceives as inconsistencies in
others' arguments or behaviors. He emphasizes the importance of substantive
debates and accurate information in public discourse.
"""
recap="""Here's a comprehensive summary of the topics discussed in the collection of summaries, organized into main topics and smaller details:

<h2>Main Topics</h2>

<h3>1. Content Creation and Streaming</h3>
<ul>
  <li><strong>Twitch and streaming:</strong> Destiny expresses frustration with Twitch, criticizing the current state of political content on the platform</li>
  <li><strong>Relationships with other streamers:</strong> Mentions being on good terms with several Twitch streamers</li>
  <li><strong>Kit (streaming platform):</strong> Discusses Kit's potential to compete with Twitch</li>
  <li><strong>Collaboration with other creators:</strong> Expresses reluctance due to differences in approach and audience expectations</li>
</ul>

<h3>2. Political Commentary and Debates</h3>
<ul>
  <li><strong>Criticism of political commentators:</strong> Particularly those who made incorrect predictions about COVID-19</li>
  <li><strong>Discussion of political extremes:</strong> Potential for extremes to work together, drawing parallels to historical events</li>
  <li><strong>Science and politics:</strong> Criticizes misrepresentation of scientific facts for political purposes</li>
  <li><strong>Israel-Palestine conflict:</strong> References to debates and discussions on this topic</li>
</ul>

<h3>3. Technical Issues and Discussions</h3>
<ul>
  <li><strong>Video file management:</strong> Issues with large video files and potential solutions</li>
  <li><strong>Russian bot operation analysis:</strong> In-depth discussion of a potential Russian bot operation on Twitter, focusing on error messages and technical aspects</li>
</ul>

<h3>4. Personal Life and Relationships</h3>
<ul>
  <li><strong>Work-life balance:</strong> Discusses the relationship between career success and personal life</li>
  <li><strong>Relationship discussions:</strong> Comments on breakups and relationship dynamics</li>
</ul>

<h2>Smaller Details and Brief Mentions</h2>

<ul>
  <li>Upcoming events and travel plans</li>
  <li>Typing speed and tests</li>
  <li>Current events (e.g., protest group damaging Stonehenge)</li>
  <li>Personal stance on issues and desire for fair treatment in online discourse</li>
  <li>Mental state and need for emotional organization</li>
  <li>Brief mentions of historical atrocities (Holocaust, Holodomor, Great Leap Forward)</li>
  <li>Music and cultural gatekeeping</li>
  <li>January 6th event</li>
  <li>Merchandise promotion</li>
  <li>YouTube drama</li>
  <li>News story about a 12-year-old Jewish girl in Paris</li>
  <li>Cocaine-related incident involving a 9-year-old</li>
  <li>Qatar's relationship with Hamas and Al Jazeera</li>
  <li>Douglas Murray's comments on Israel-Hamas conflict</li>
  <li>Age of consent laws and pedophilia (mentioned in confusion)</li>
  <li>Illegal firearm modifications</li>
</ul>

<p>Overall, Destiny's tone throughout these discussions is often critical, skeptical, and analytical. He frequently expresses frustration with misinformation, personal attacks, and what he perceives as inconsistencies in others' arguments or behaviors. He emphasizes the importance of substantive debates and accurate information in public discourse.</p>
"""

# grab which data is associated with each title
import re
def extract_titles_and_list_items(recap):
    title_pattern=re.compile(r'<h3>(.*?)</h3>')
    list_item_pattern=re.compile(r'<li>(.*?)</li>')
    titles=title_pattern.findall(recap)
    list_items=list_item_pattern.findall(recap)
    return titles, list_items

titles, list_items=extract_titles_and_list_items(recap)

# %%
test_response=await saf.recap_zoomed_in_generator.annotate_zoom_chunks(summaized_chunks=trancript_model_data.summarized_chunks, recap=recap)

# %%
print(test_response)

# %%
print(trancript_model_data.summarized_chunks[8]["summary"])

# %%
print(all_transcript_model_data[0].meta)

# %%
annotated_chunks="""Based on the recap and summaries provided, here are recommendations for summary chunks that could be used to create more detailed panes for each of the main topics and smaller details:

Large topics:

{{{"Twitch and Streaming": [0, 5], "content": ["<strong>Twitch and streaming</strong> Destiny discusses his relationship with Twitch, expressing frustration about being unable to respond to slander and threats on the platform. He criticizes the current state of political content on Twitch, saying it has become less collaborative and more focused on individual streamers' clout.", "<strong>Twitch and streaming</strong> Destiny mentions being on good terms with several Twitch streamers, including Mizkif, Dr. K, and Asmongold. He emphasizes that he doesn't want blind defense from others, just fair treatment and acknowledgment when he's correct."]}}}

{{{"Collaborations and Relationships with Other Creators": [6, 8], "content": ["<strong>Collaborations and Relationships with Other Creators</strong> Destiny criticizes Hasan's approach to engaging with other content creators, suggesting Hasan only engages when he thinks he can gain clout or handle the situation.", "<strong>Collaborations and Relationships with Other Creators</strong> The speaker (Destiny) discusses collaborating with other content creators, expressing reluctance due to differences in approach and audience expectations."]}}}

{{{"Personal Stance and Approach": [0, 1], "content": ["<strong>Personal Stance and Approach</strong> Destiny emphasizes that he speaks out on issues he believes are correct, not to defend specific groups or individuals. He expresses discomfort with being seen as a spokesperson for any particular cause.", "<strong>Personal Stance and Approach</strong> Destiny expresses frustration with personal attacks that aren't accompanied by substantive arguments. He's open to criticism of his ideas but dislikes baseless personal attacks."]}}}

{{{"Current Events and Debates": [0, 1, 5], "content": ["<strong>Current Events and Debates</strong> He mentions a protest group damaging Stonehenge with orange spray paint.", "<strong>Current Events and Debates</strong> Destiny discusses leveraging his mainstream credibility from large debates. He expresses frustration with a particular individual who initially claimed willingness to debate but later backtracked.", "<strong>Current Events and Debates</strong> Reference to a debate or discussion about the Israel-Palestine conflict, with someone challenging Destiny's knowledge on the topic."]}}}

{{{"Media and Misinformation": [1, 4, 5], "content": ["<strong>Media and Misinformation</strong> He's triggered by ignorant people spreading misinformation in large spaces.", "<strong>Media and Misinformation</strong> This transcript covers several topics and sentiments expressed by the speaker, Destiny: An alleged exposure of Russian bots on Twitter supporting Trump, which Destiny is skeptical about.", "<strong>Media and Misinformation</strong> Criticism of media reporting on unsubstantiated rumors and its potential to cause division."]}}}

{{{"Israel-Palestine Conflict": [5, 6], "content": ["<strong>Israel-Palestine Conflict</strong> Reference to a debate or discussion about the Israel-Palestine conflict, with someone challenging Destiny's knowledge on the topic.", "<strong>Israel-Palestine Conflict</strong> Discussion about Hassan Piker's stance on Israel and Palestine, with Destiny questioning Hassan's consistency and motives."]}}}

{{{"Video File Management": [0], "content": ["<strong>Video File Management</strong> Destiny discusses issues with large video files from his cameras and explores options for compressing or managing these files for his editor in Australia. He goes into technical details about file sizes, upload speeds, and potential solutions."]}}}

{{{"Russian Bot Analysis": [3, 4, 5], "content": ["<strong>Russian Bot Analysis</strong> An in-depth analysis of the alleged Russian bot exposure, focusing on the technical aspects of how such a bot might function and why the reported error seems suspicious.", "<strong>Russian Bot Analysis</strong> Destiny expresses skepticism about its authenticity.", "<strong>Russian Bot Analysis</strong> Discussion about a Twitter bot that was allegedly exposed as a Russian disinformation campaign. The speaker (Destiny) is skeptical of the claims and suggests that the account suspension could be for various reasons."]}}}

Smaller topics:

{{{"Schedule and Travel": 0}}}
{{{"Typing Speed": 0}}}
{{{"Mental State": 1}}}
{{{"Work-Life Balance": 2}}}
{{{"Music and Cultural Gatekeeping": 2}}}
{{{"Relationship Discussions": 2}}}
{{{"January 6th Event": 2}}}
{{{"Merchandise Promotion": 8}}}
{{{"Basketball Game Scene": 8}}}
{{{"Courtroom and Prison Scenario": 8}}}
{{{"Illegal Firearm Modifications": 8}}}
{{{"Personal Interactions": 8}}}
"""

# %%
# parse the annotated_chunks
import re
def parse_annotated_chunks(annotated_chunks):
    # find everything
    pattern=re.compile(r'\{\{\{.*?\}\}\}')
    chunks=pattern.findall(annotated_chunks)

    # replace the triple curly braces with single curly braces
    chunks=[chunk.replace("{{{", "{").replace("}}}", "}") for chunk in chunks]
    return chunks

# %%
test_annotated_chunks=parse_annotated_chunks(annotated_chunks)

# %%
print(test_annotated_chunks[0])

# %%
topic_prompt_str=""
annotated_chunk_dict=json.loads(test_annotated_chunks[0])
chunk_indexes=[]
for key, value in annotated_chunk_dict.items():
    if key=="content":
        topic_prompt_str+="\n"+", ".join(value)
    else:
        chunk_indexes=value
        topic_prompt_str+=key

transcript_chunks_str=""
for chunk_index in chunk_indexes:
    transcript_chunks_str+=trancript_model_data.summarized_chunks[chunk_index]["transcript"]+"\n\n"

# %%
chunk_annotations_str=test_response
summarized_chunks=trancript_model_data.summarized_chunks

pattern=re.compile(r'\{\{\{.*?\}\}\}')
chunk_annotations_temp=pattern.findall(chunk_annotations_str)
chunk_annotations_temp=[chunk_annotation.replace("{{{", "{").replace("}}}", "}") for chunk_annotation in chunk_annotations_temp]
chunk_annotations=[]
for chunk_annotation in chunk_annotations_temp:
    chunk_annotations.append(json.loads(chunk_annotation))

# turn summarized chunks into prompt contexts
topic_prompts=[]
for chunk_annotation in chunk_annotations:
    # get topic prompt and chunk indexes for transcript prompt
    temp_prompt_str=""
    chunk_indexes=[]
    for key, value in chunk_annotation.items():
        if key=="content":
            temp_prompt_str+="\n"+", ".join(value)
        else:
            chunk_indexes=value
            temp_prompt_str+=key
    topic_prompts.append(temp_prompt_str)
    
    # get transcript prompt from the indexes
    transcript_chunks_str=""
    for chunk_index in chunk_indexes:
        transcript_chunks_str+=summarized_chunks[chunk_index]["transcript"]+"\n\n"

# %%
trancript_model_data=await saf.grab_transcript_data(video_id)
chunk_annotations_str=await saf.recap_zoomed_in_generator.annotate_zoom_chunks(summaized_chunks=trancript_model_data.summarized_chunks, recap=recap)
chunk_annotations, topic_prompts, transcript_chunks_prompts=saf.recap_zoomed_in_generator.prepare_zoom_inputs(trancript_model_data.summarized_chunks, chunk_annotations_str)
zooms=await saf.recap_zoomed_in_generator.prepare_zoom_inputs(topic_prompts, transcript_chunks_prompts)

# %%
print(recap)

# %%
# Reset saf 
del sys.modules['destinyapp.api.ServerAiFunctions']
import destinyapp.api.ServerAiFunctions as saf
reload(saf)

# %%
zoom_response=await saf.recap_zoomed_in_generator.generate_zoom(transcript_chunks_str=transcript_chunks_str, topic_prompt_str=topic_prompt_str)

# %%
print(zoom_response)

# %%
transcript_chunks_str

# %%
print(zoom_response)

# %%
print(zoom_response)

# %% [markdown]
# # all zoom gen

# %%
# Reset saf 
del sys.modules['destinyapp.api.ServerAiFunctions']
import destinyapp.api.ServerAiFunctions as saf
reload(saf)

# %%
trancript_model_data=await saf.grab_transcript_data(video_id)
chunk_annotations_str=await saf.recap_zoomed_in_generator.annotate_zoom_chunks(summaized_chunks=trancript_model_data.summarized_chunks, recap=recap)
chunk_annotations, topic_prompts, transcript_chunks_prompts=saf.recap_zoomed_in_generator.prepare_zoom_inputs(trancript_model_data.summarized_chunks, chunk_annotations_str)
zooms=await saf.recap_zoomed_in_generator.generate_all_zooms(topic_prompts, transcript_chunks_prompts)

# %%
zooms=await saf.recap_zoomed_in_generator.generate_all_zooms(topic_prompts, transcript_chunks_prompts)

# %%
print(topic_prompts[0])
print("\n")
print(zooms[0])

# %%
reformt_dict=await saf.recap_zoomed_in_generator.reformat_recap(recap, topic_prompts, zooms)

# %%
print(recap)

# %%
# parse the recap to get the [{"title": list_title, "list_items": list_items}] for each title and subsequent list items
# basically find the stuff between headed tags, that is the title, continue until you see a <ul> tag which is the start of the list items


# title_pattern=re.compile(r'<h3>(.*?)</h3>')
# list_item_pattern=re.compile(r'<li>(.*?)</li>')
# titles=title_pattern.findall(recap)
# list_items=list_item_pattern.findall(recap)
    
from bs4 import BeautifulSoup

soup = BeautifulSoup(recap, 'html.parser')

# Find all the titles and list items
data = []
for title in soup.find_all('h3'):
    list_items = []
    ul_tag = title.find_next_sibling('ul')
    if ul_tag:
        for li in ul_tag.find_all('li'):
            list_items.append(li.text)
    data.append({"title": title.text, "list_items": list_items})

for title in soup.find_all('h2'):
    list_items = []
    ul_tag = title.find_next_sibling('ul')
    if ul_tag:
        for li in ul_tag.find_all('li'):
            list_items.append(li.text)
    data.append({"title": title.text, "list_items": list_items})

print(data)

    # return the titles and list items
    # return [{"title": title, "list_items": list_items} for title, list_items in zip(titles, list_items)]

# %%
list(chunk_annotation.keys())[0]

# %%
chunk_annotations

# %%
filled_data=[]

for piece in data:
    for i, chunk_annotation  in enumerate(chunk_annotations):
        if list(chunk_annotation.keys())[0] in piece["title"]:
            html_list="<ul>"
            for list_item in piece["list_items"]:
                html_list+=f"<li>{list_item}</li>"
            html_list+="</ul>"
            filled_data.append({"title":piece["title"], "content":html_list})
            filled_data[-1]["zoom"]=zooms[i]

    if piece["title"]=='Smaller Details and Brief Mentions':
        for small_piece in piece["list_items"]:
            for i, chunk_annotation  in enumerate(chunk_annotations):
                if list(chunk_annotation.keys())[0] in small_piece:
                    filled_data.append({"title":small_piece})
                    filled_data[-1]["zoom"]=zooms[i]

# %%
# import html
from IPython.display import display, Markdown, HTML

# %%
display(HTML(recap))

# %%
filled_data

# %%
print(data)

# %%
len_zooms=0
for zoom in zooms:
    len_zooms+=len(zoom)
print(len_zooms)

# %%
# grab which data is associated with each title
import re
def extract_titles_and_list_items(recap):
    title_pattern=re.compile(r'<h3>(.*?)</h3>')
    list_item_pattern=re.compile(r'<li>(.*?)</li>')
    titles=title_pattern.findall(recap)
    list_items=list_item_pattern.findall(recap)
    return titles, list_items

titles, list_items=extract_titles_and_list_items(recap)

# %%
titles

# %%
list_items

# %% [markdown]
# # Hook 1m3

# %% [markdown]
# # Chat v1@

# %%
# reload
del sys.modules['destinyapp.api.ServerAiFunctions']
import destinyapp.api.ServerAiFunctions as saf
reload(saf)

# %%
yt_id="3kJr7ODrwNw"

import datetime
from chat_downloader import ChatDownloader
import math

# %%
video_meta_data = ChatDownloader().get_chat('https://www.youtube.com/watch?v='+yt_id)

# get the chat data
all_chat_messages=[]
for chat in video_meta_data.chat:
    all_chat_messages.append(chat)

# Simplify the chat data
simplified_messsages=[]
for message in all_chat_messages:
    simplified_messsages.append({"name": message["author"]["name"], "message": message["message"], "time": message["time_text"]})

# %%
# get the transcript
transcript_data=await saf.grab_transcript_data(yt_id)
transcript=transcript_data.transcript
start_end_char=transcript_data.summarized_chunks[0]["char_start_finsih_indexes"]
transcript=transcript[start_end_char[0]:start_end_char[1]]
linked_transcript=transcript_data.linked_transcript

# get the messages in the segment
start_time=saf.get_time_at_char_count(start_end_char[0], linked_transcript)
finish_time=saf.get_time_at_char_count(start_end_char[1], linked_transcript)
segment_messages=saf.get_chats_in_start_end(simplified_messsages,  int(start_time), int(finish_time))

# %%
# propose a split size and then get the indexes to split the chat into batches
chat_processing_batches=[]
set_batch_size=150
if len(segment_messages)<set_batch_size:
    batch_size=len(segment_messages)
else:
    batch_size=math.ceil(len(segment_messages)/round(len(segment_messages)//set_batch_size))
# Make set of indexes to split the chat into batches
batch_indexes=[i for i in range(0, len(segment_messages), batch_size)]
for i, index in enumerate(batch_indexes):
    if index==batch_indexes[-1]:
        chat_processing_batches.append(segment_messages[index:])
    else:
        chat_processing_batches.append(segment_messages[index:batch_indexes[i+1]])
# Create chat str batches
chat_segment_str_batches=[]
for i, batch in enumerate(chat_processing_batches):
    print("Len batch", len(batch))
    chat_segment_str=""
    for j, message in enumerate(batch):
        message_at_time=message["time"]
        message_content=message["message"]
        temp_str=f"{j}: {message_content}"
        chat_segment_str+=temp_str+"\n"
    chat_segment_str_batches.append(chat_segment_str)

# %%
# bot_analysis=await saf.analyze_chat(transcript_data.summarized_chunks[0]["summary"], chat_segment_str_batches[0])
bot_analysis=await saf.analyze_chat(transcript_data.summarized_chunks[0]["summary"], chat_segment_str_batches[3])

# %%
print(bot_analysis.split("\n")[-1])

# %%
# total cost
0.0025700000000000002*(len(simplified_messsages)/150)

# %%
chat_annotations={}
for line in bot_analysis.split("\n"):
    number=line.split(":")[0]
    if number.isdigit():
        full_reason=line.split(":")[1].strip()
        serious=full_reason.startswith("yes")
        chat_annotations[number]={"full": full_reason, "serious": serious}

# %%
print(chat_annotations['0'])

# %%
stats={}
stats["serious"]=0
for chat_annotation in chat_annotations:
    if chat_annotations[chat_annotation]["serious"]:
        stats["serious"]+=1

print(stats)

# %%
simplified_messsages[587]

# %%
for i, chat_annotation in enumerate(chat_annotations):
    if chat_annotations[chat_annotation]["serious"]:
        y_n="y"
    else:
        y_n="n"
    print(y_n, chat_segment_str_batches[3].split("\n")[i])#, "                              ANALYSIS", chat_annotations[chat_annotation]["full"])

# %%
start_time

# %%
simplified_messsages[20]

# %%
print(chat_segment_str_batches[0])

# %% [markdown]
# # process all chat messages

# %%
# reload
del sys.modules['destinyapp.api.ServerAiFunctions']
import destinyapp.api.ServerAiFunctions as saf
reload(saf)
# Out:
# <module 'destinyapp.api.ServerAiFunctions' from 'd:\\DestinyFolder\\DestinyRecaps\\DestinyRecapsApi\\serverproject\\destinyapp\\api\\ServerAiFunctions.py'>

# %%
yt_id="3kJr7ODrwNw"

import datetime
from chat_downloader import ChatDownloader
import math

# %%
# GET TRANSCRIPT
transcript_data=await saf.grab_transcript_data(yt_id)
transcript=transcript_data.transcript
linked_transcript=transcript_data.linked_transcript

# %%
# GET BASE CHAT DATA
video_meta_data = ChatDownloader().get_chat('https://www.youtube.com/watch?v='+yt_id)

# get the chat data
all_chat_messages=[]
for chat in video_meta_data.chat:
    all_chat_messages.append(chat)

# Simplify the chat data
simplified_messsages=[]
for message in all_chat_messages:
    simplified_messsages.append({"name": message["author"]["name"], "message": message["message"], "time": message["time_text"]})

# %%
# make tasks and reference data
tasks=[]
input_data=[]

for summarized_chunk in transcript_data.summarized_chunks:
    # get the transcript
    start_end_char=summarized_chunk["char_start_finsih_indexes"]
    transcript=transcript_data.transcript[start_end_char[0]:start_end_char[1]]

    # get the messages in the segment
    start_time=saf.get_time_at_char_count(start_end_char[0], linked_transcript)
    finish_time=saf.get_time_at_char_count(start_end_char[1], linked_transcript)
    segment_messages=saf.get_chats_in_start_end(simplified_messsages,  int(start_time), int(finish_time))

    # # CREATE CHAT BATCHES
    # propose a split size and then get the indexes to split the chat into batches
    chat_processing_batches=[]
    set_batch_size=150
    if len(segment_messages)<set_batch_size:
        batch_size=len(segment_messages)
    else:
        batch_size=math.ceil(len(segment_messages)/round(len(segment_messages)//set_batch_size))
    # Make set of indexes to split the chat into batches
    batch_indexes=[i for i in range(0, len(segment_messages), batch_size)]
    for i, index in enumerate(batch_indexes):
        if index==batch_indexes[-1]:
            chat_processing_batches.append(segment_messages[index:])
        else:
            chat_processing_batches.append(segment_messages[index:batch_indexes[i+1]])
    # Create chat str batches
    chat_segment_str_batches=[]
    for i, batch in enumerate(chat_processing_batches):
        print("Len batch", len(batch))
        chat_segment_str=""
        for j, message in enumerate(batch):
            message_at_time=message["time"]
            message_content=message["message"]
            temp_str=f"{j}: {message_content}"
            chat_segment_str+=temp_str+"\n"
        chat_segment_str_batches.append(chat_segment_str)

    for i, chat_batch in enumerate(chat_segment_str_batches):
        input_data.append({"transcript": transcript, "chat_batch": chat_batch, "segment_messages": chat_processing_batches[i]})
        tasks.append(saf.analyze_chat(transcript, chat_batch))
# Out:
# 602
# Len batch 151
# Len batch 151
# Len batch 151
# Len batch 149
# 451
# Len batch 151
# Len batch 151
# Len batch 149
# 947
# Len batch 158
# Len batch 158
# Len batch 158
# Len batch 158
# Len batch 158
# Len batch 157
# 506
# Len batch 169
# Len batch 169
# Len batch 168
# 430
# Len batch 215
# Len batch 215
# 998
# Len batch 167
# Len batch 167
# Len batch 167
# Len batch 167
# Len batch 167
# Len batch 163
# 479
# Len batch 160
# Len batch 160
# Len batch 159
# 906
# Len batch 151
# Len batch 151
# Len batch 151
# Len batch 151
# Len batch 151
# Len batch 151
# Cumulative count 85273
# 1215
# Len batch 152
# Len batch 152
# Len batch 152
# Len batch 152
# Len batch 152
# Len batch 152
# Len batch 152
# Len batch 151

# %%
# # RUN TASKS
# split the tasks into batches of about 20 but make them as even as possible with math
split_up_tasks=[]
proposed_batch_size=20
batch_size=math.ceil(len(tasks)/round(len(tasks)//proposed_batch_size))
batch_indexes=[i for i in range(0, len(tasks), batch_size)]
for i, index in enumerate(batch_indexes):
    if index==batch_indexes[-1]:
        split_up_tasks.append(tasks[index:])
    else:
        split_up_tasks.append(tasks[index:batch_indexes[i+1]])

# run the tasks
all_chat_analysis=[]
for tasks_batch in split_up_tasks:
    all_chat_analysis+=await asyncio.gather(*tasks_batch)
# Out:
# 0.0027955000000000002
# 0.0032695000000000003
# 0.0027722500000000004
# 0.002879
# 0.0030237500000000004
# 0.0032790000000000002
# 0.00320475
# 0.00335975
# 0.00349875
# 0.0029170000000000003
# 0.0037065000000000006
# 0.00286825
# 0.0028905
# 0.0029835
# 0.0037512500000000002
# 0.003575
# 0.00370475
# 0.005111500000000001
# 0.0041765000000000005
# 0.005547750000000001
# 0.0058825
# 0.0024805
# 0.0027045000000000003
# 0.003067
# 0.0032387500000000003
# 0.0033367500000000003
# 0.0033462500000000003
# 0.0038860000000000006
# 0.00248475
# 0.0024705000000000005
# 0.0029435
# 0.002822
# 0.0029935
# 0.003117
# 0.003235
# 0.00349525
# 0.0032747500000000003
# 0.0036467500000000003
# 0.00345425
# 0.0033035
# 0.0037655

# %%
# Organize Analysis responses
all_chat_annotations=[]
error_count=0
for i, chat_analysis in enumerate(all_chat_analysis):
    chat_annotations={}
    for c, line in enumerate(chat_analysis.split("\n")):
        number=line.split(":")[0]
        if number.isdigit():
            full_reason=line.split(":")[1].strip()
            serious=full_reason.startswith("yes")
            try:
                chat_annotations[number]={"full": full_reason, "serious": serious, "chat_data": input_data[i]["segment_messages"][int(number)], "transcript":input_data[i]["transcript"]}
            except:
                error_count+=1
    all_chat_annotations.append(chat_annotations)
print(error_count)

ordered_chat_annotations={}
message_count=0
stats={}
stats["serious"]=0
for chat_annotations in all_chat_annotations:
    for chat_annotation in list(chat_annotations.values()):
        ordered_chat_annotations[simplified_messsages.index(chat_annotation["chat_data"])]=chat_annotation
        if chat_annotation["serious"]:
            stats["serious"]+=1
        message_count+=1
    
print(message_count)
print(stats)
# Out:
# 8
# 6533
# {'serious': 1842}

# %%
def print_chat_annotation(chat_annotation):
    print(chat_annotation["full"], chat_annotation["serious"], chat_annotation["chat_data"])
chat_annotations=all_chat_annotations[0]
print_chat_annotation(chat_annotations['1'])
chat_annotations=all_chat_annotations[1]
print_chat_annotation(chat_annotations['1'])
chat_annotations=all_chat_annotations[2]
print_chat_annotation(chat_annotations['1'])
chat_annotations=all_chat_annotations[3]
print_chat_annotation(chat_annotations['1'])
# Out:
# yes - Serious message about Kendrick Lamar's Juneteenth show True {'name': 'Esteban', 'message': 'Kendrick Juneteenth show soon :cold_face:', 'time': '2:25'}
# no-(casual chat) False {'name': 'undesirable🏳️\u200d🌈', 'message': 'kimberly dindonuffin', 'time': '9:15'}
# yes-(a serious suggestion about remote editing) True {'name': 'Zachary Isom', 'message': "Almost all editing is done remotely anyway because the file you're editing is stored remotely.", 'time': '14:45'}
# no-(nonsensical message) False {'name': 'Cynicram', 'message': 'chatgpt ass language ', 'time': '17:32'}

# %%
list_chat_annotations=list(ordered_chat_annotations.values())
stats={}
stats["serious"]=0
serious_messages=[]

for key, chat_annotation in ordered_chat_annotations.items():
    if chat_annotation["serious"]:
        stats["serious"]+=1
        serious_messages.append({key: chat_annotation})
    
print(stats)
print(len(list_chat_annotations))
# Out:
# {'serious': 1808}
# 6415

# %%
for serious_message in serious_messages:
    for key, value in serious_message.items():
        print(simplified_messsages[key], value["chat_data"], value["full"])
# Out:
# {'name': 'Esteban', 'message': 'Kendrick Juneteenth show soon :cold_face:', 'time': '2:25'} {'name': 'Esteban', 'message': 'Kendrick Juneteenth show soon :cold_face:', 'time': '2:25'} yes - Serious message about Kendrick Lamar's Juneteenth show
# {'name': 'alpha 🏳️\u200d🌈', 'message': 'W envi :_destinyFeelsGood:', 'time': '2:29'} {'name': 'alpha 🏳️\u200d🌈', 'message': 'W envi :_destinyFeelsGood:', 'time': '2:29'} yes - Positive reaction to Destiny's stream
# {'name': 'arcadebishop ', 'message': 'Yerrrrr also W envi', 'time': '2:43'} {'name': 'arcadebishop ', 'message': 'Yerrrrr also W envi', 'time': '2:43'} yes - Positive reaction to Destiny's stream
# {'name': 'Isaac Lester', 'message': 'Watch Alex o Connor’s most recent debate!', 'time': '3:00'} {'name': 'Isaac Lester', 'message': 'Watch Alex o Connor’s most recent debate!', 'time': '3:00'} yes - Recommendation to watch a debate
# {'name': 'WIbigdog', 'message': 'Juneteenth marks which event exactly? The emancipation proclamation?', 'time': '3:12'} {'name': 'WIbigdog', 'message': 'Juneteenth marks which event exactly? The emancipation proclamation?', 'time': '3:12'} yes - Question about Juneteenth
# {'name': 'Elote-Man94', 'message': 'W stream', 'time': '3:14'} {'name': 'Elote-Man94', 'message': 'W stream', 'time': '3:14'} yes - Positive reaction to the stream
# {'name': 'james smith', 'message': 'Louisiana putting 10 commandments in classrooms', 'time': '3:20'} {'name': 'james smith', 'message': 'Louisiana putting 10 commandments in classrooms', 'time': '3:20'} yes - Message about Louisiana putting 10 commandments in classrooms
# {'name': 'Elote-Man94', 'message': 'Happy Juneteenth queen', 'time': '3:27'} {'name': 'Elote-Man94', 'message': 'Happy Juneteenth queen', 'time': '3:27'} yes - Positive message about Juneteenth
# {'name': 'Issa Osa', 'message': "what's happening with Alex o Connor?", 'time': '3:29'} {'name': 'Issa Osa', 'message': "what's happening with Alex o Connor?", 'time': '3:29'} yes - Question about what happened with Alex O'Connor
# {'name': 'Kyle', 'message': 'Show on what ?', 'time': '3:35'} {'name': 'Kyle', 'message': 'Show on what ?', 'time': '3:35'} yes - Question about what Destiny is showing
# {'name': 'Esteban', 'message': 'Alex O’Connor is chill like that ', 'time': '3:36'} {'name': 'Esteban', 'message': 'Alex O’Connor is chill like that ', 'time': '3:36'} yes - Positive message about Alex O'Connor
# {'name': 'Nightbot', 'message': 'Email me at contact@destiny.gg', 'time': '3:47'} {'name': 'Nightbot', 'message': 'Email me at contact@destiny.gg', 'time': '3:47'} yes - Providing an email address
# {'name': 'alpha 🏳️\u200d🌈', 'message': '@Destiny react to kendrick lamars juneteenth concert for easy content', 'time': '3:49'} {'name': 'alpha 🏳️\u200d🌈', 'message': '@Destiny react to kendrick lamars juneteenth concert for easy content', 'time': '3:49'} yes - Recommendation for Destiny to react to Kendrick Lamar's Juneteenth concert
# {'name': 'Aisha', 'message': 'Oh yea I love Alex what happened', 'time': '3:49'} {'name': 'Aisha', 'message': 'Oh yea I love Alex what happened', 'time': '3:49'} yes - Positive message about Alex O'Connor
# {'name': 'Aisha', 'message': 'Oh tomorrow ', 'time': '4:16'} {'name': 'Aisha', 'message': 'Oh tomorrow ', 'time': '4:16'} yes - Message about tomorrow
# {'name': 'XavierKhrone', 'message': 'yooo alex BASED', 'time': '4:22'} {'name': 'XavierKhrone', 'message': 'yooo alex BASED', 'time': '4:22'} yes - Positive message about Alex O'Connor being based
# {'name': 'Rudy Mendoza', 'message': 'like the video ', 'time': '4:26'} {'name': 'Rudy Mendoza', 'message': 'like the video ', 'time': '4:26'} yes - Recommendation to like the video
# {'name': 'astrolabia106', 'message': 'oh thats so cool - i lovee Alex', 'time': '4:36'} {'name': 'astrolabia106', 'message': 'oh thats so cool - i lovee Alex', 'time': '4:36'} yes - Positive message about Alex O'Connor
# {'name': 'Nightbot', 'message': 'See upcoming events at https://destiny.gg/schedule', 'time': '4:48'} {'name': 'Nightbot', 'message': 'See upcoming events at https://destiny.gg/schedule', 'time': '4:48'} yes - Providing a link to the schedule
# {'name': 'socomchamp00', 'message': "@take a gander I don't really consume his content but the few times I have, and she was on, she seemed super cool.", 'time': '5:20'} {'name': 'socomchamp00', 'message': "@take a gander I don't really consume his content but the few times I have, and she was on, she seemed super cool.", 'time': '5:20'} yes - Positive message about a person
# {'name': 'Henry Boadle', 'message': 'break them into more workable chunks? ', 'time': '5:41'} {'name': 'Henry Boadle', 'message': 'break them into more workable chunks? ', 'time': '5:41'} yes - Suggestion about breaking the files into smaller chunks
# {'name': 'Ryan', 'message': 'How hard would it be to make a copy and have it delivered physically?', 'time': '5:52'} {'name': 'Ryan', 'message': 'How hard would it be to make a copy and have it delivered physically?', 'time': '5:52'} yes - Suggestion about physically mailing a copy
# {'name': 'Esteban', 'message': 'Who let Dinesh debate Alex it was over form the start ', 'time': '5:53'} {'name': 'Esteban', 'message': 'Who let Dinesh debate Alex it was over form the start ', 'time': '5:53'} yes - Negative message about Dinesh debating Alex
# {'name': 'Drealest', 'message': 'Y’all get those ai chat summarys?', 'time': '5:57'} {'name': 'Drealest', 'message': 'Y’all get those ai chat summarys?', 'time': '5:57'} yes - Question about the AI chat summaries
# {'name': 'Take A Gander', 'message': '@socomchamp00 Yeah she is, thats whats sad, Dantes jsut had to admit he didnt have the time to give to the relationship it deserved so he said nothing but support to her', 'time': '6:11'} {'name': 'Take A Gander', 'message': '@socomchamp00 Yeah she is, thats whats sad, Dantes jsut had to admit he didnt have the time to give to the relationship it deserved so he said nothing but support to her', 'time': '6:11'} yes - Message about a relationship
# {'name': 'Ali Ahmad', 'message': 'just ship the footage in the mail on ssd or something', 'time': '6:19'} {'name': 'Ali Ahmad', 'message': 'just ship the footage in the mail on ssd or something', 'time': '6:19'} yes - Suggestion about mailing the footage on an SSD
# {'name': 'Azem', 'message': 'Has anyone ever heard august’ voice? Just realized I’ve been heat for years and years and NEVER heard him speak LOL. ', 'time': '6:25'} {'name': 'Azem', 'message': 'Has anyone ever heard august’ voice? Just realized I’ve been heat for years and years and NEVER heard him speak LOL. ', 'time': '6:25'} yes - Question about hearing August's voice
# {'name': 'lydovexer', 'message': 'Make copies of the physical drives and mail them', 'time': '6:29'} {'name': 'lydovexer', 'message': 'Make copies of the physical drives and mail them', 'time': '6:29'} yes - Suggestion about making copies and mailing them
# {'name': 'Johnjackjack', 'message': 'really feel like 2k is standard now adays', 'time': '6:30'} {'name': 'Johnjackjack', 'message': 'really feel like 2k is standard now adays', 'time': '6:30'} yes - Message about 2K being standard
# {'name': 'K B', 'message': 'AI chat summary says only one of you is complaining about your treatment in chat. LOL. Which one of you is it?', 'time': '6:35'} {'name': 'K B', 'message': 'AI chat summary says only one of you is complaining about your treatment in chat. LOL. Which one of you is it?', 'time': '6:35'} yes - Question about the AI chat summary
# {'name': 'woahitskyle', 'message': 'can you just copy them to a drive and mail them', 'time': '6:54'} {'name': 'woahitskyle', 'message': 'can you just copy them to a drive and mail them', 'time': '6:54'} yes - Suggestion about copying the files to a drive and mailing them
# {'name': 'XavierKhrone', 'message': "How do y'all see the AI summaries?", 'time': '6:56'} {'name': 'XavierKhrone', 'message': "How do y'all see the AI summaries?", 'time': '6:56'} yes - Question about seeing the AI summaries
# {'name': 'Horvath Sogranfume', 'message': 'im satisfied with my treatment in chat', 'time': '7:28'} {'name': 'Horvath Sogranfume', 'message': 'im satisfied with my treatment in chat', 'time': '7:28'} yes - Message about being satisfied with chat treatment
# {'name': 'Israel Garcia', 'message': 'Yeah where is the ai chat summary ', 'time': '7:28'} {'name': 'Israel Garcia', 'message': 'Yeah where is the ai chat summary ', 'time': '7:28'} yes - Question about the AI chat summary
# {'name': 'socomchamp00', 'message': '@take a gander ah, the old killer of relationships...vidja games', 'time': '7:40'} {'name': 'socomchamp00', 'message': '@take a gander ah, the old killer of relationships...vidja games', 'time': '7:40'} yes - Message about video games killing relationships
# {'name': 'ant', 'message': '@xavierkhrone it just shows when you click on the stream', 'time': '7:49'} {'name': 'ant', 'message': '@xavierkhrone it just shows when you click on the stream', 'time': '7:49'} yes - Message about where the AI chat summary is shown
# {'name': 'Vojtěch Kuchař', 'message': 'kinda overkill for a webcam no?', 'time': '7:49'} {'name': 'Vojtěch Kuchař', 'message': 'kinda overkill for a webcam no?', 'time': '7:49'} yes - Question about the camera being overkill
# {'name': 'W1lh3lm', 'message': "I think it's less compression more splitting it into smaller files and sending them in batches", 'time': '7:49'} {'name': 'W1lh3lm', 'message': "I think it's less compression more splitting it into smaller files and sending them in batches", 'time': '7:49'} yes - Suggestion about splitting the files and sending in batches
# {'name': 'Cesar Vidal', 'message': 'sam harris when?', 'time': '8:00'} {'name': 'Cesar Vidal', 'message': 'sam harris when?', 'time': '8:00'} yes - Question about when Sam Harris will be on
# {'name': 'Ajmal Sohail', 'message': 'unironically, put it on a hard disk of some sorts and post it lol', 'time': '8:06'} {'name': 'Ajmal Sohail', 'message': 'unironically, put it on a hard disk of some sorts and post it lol', 'time': '8:06'} yes - Suggestion about mailing a hard drive
# {'name': 'Benjamin AVSTECH', 'message': 'MP 48265 HEVC 8000 kB a second GOP 60 or 30 and alternate to be frames. Use video Prock.', 'time': '8:08'} {'name': 'Benjamin AVSTECH', 'message': 'MP 48265 HEVC 8000 kB a second GOP 60 or 30 and alternate to be frames. Use video Prock.', 'time': '8:08'} yes - Specific technical suggestion about video settings
# {'name': 'Sean', 'message': 'Why dont u back a copy up and mail it to August Destiny?', 'time': '8:14'} {'name': 'Sean', 'message': 'Why dont u back a copy up and mail it to August Destiny?', 'time': '8:14'} yes - Suggestion about mailing a backup copy
# {'name': 'Korean Bronze VI', 'message': 'Are you doing 6k Open gate? or just 4k?', 'time': '8:34'} {'name': 'Korean Bronze VI', 'message': 'Are you doing 6k Open gate? or just 4k?', 'time': '8:34'} yes - Question about the camera resolution
# {'name': 'Anthony Aguilar', 'message': 'lossless compression would mean converting the file to another lossless format that would be smaller in nature I guess', 'time': '8:41'} {'name': 'Anthony Aguilar', 'message': 'lossless compression would mean converting the file to another lossless format that would be smaller in nature I guess', 'time': '8:41'} yes - Explanation of lossless compression
# {'name': 'Benjamin AVSTECH', 'message': 'MP4 hEVC h.265 ', 'time': '8:42'} {'name': 'Benjamin AVSTECH', 'message': 'MP4 hEVC h.265 ', 'time': '8:42'} yes - Specific technical suggestion about video format
# {'name': 'Take A Gander', 'message': '@socomchamp00 Heh yeah, but even more longstanding ender of relationships, career', 'time': '8:48'} {'name': 'Take A Gander', 'message': '@socomchamp00 Heh yeah, but even more longstanding ender of relationships, career', 'time': '8:48'} yes - Message about video games ending relationships
# {'name': 'Gabreyes093', 'message': 'Has he explained how he is releasing the Israel footage?', 'time': '8:55'} {'name': 'Gabreyes093', 'message': 'Has he explained how he is releasing the Israel footage?', 'time': '8:55'} yes - Question about how Israel footage is being released
# {'name': 'Johan Nilsson', 'message': 'Is Israel content published yet?', 'time': '8:55'} {'name': 'Johan Nilsson', 'message': 'Is Israel content published yet?', 'time': '8:55'} yes - Question about whether Israel content is published yet
# {'name': 'Benjamin AVSTECH', 'message': 'Is this for online use?', 'time': '9:04'} {'name': 'Benjamin AVSTECH', 'message': 'Is this for online use?', 'time': '9:04'} yes - Question about whether this is for online use
# {'name': 'tsphantom', 'message': "Why don't you just sync a folder with him with something like Resilio sync and send it to him directly?", 'time': '9:46'} {'name': 'tsphantom', 'message': "Why don't you just sync a folder with him with something like Resilio sync and send it to him directly?", 'time': '9:46'} yes-(suggesting a solution to the file transfer issue)
# {'name': 'Benjamin AVSTECH', 'message': 'Yea you compress to h265 optimized for streaming', 'time': '9:52'} {'name': 'Benjamin AVSTECH', 'message': 'Yea you compress to h265 optimized for streaming', 'time': '9:52'} yes-(suggesting a solution to the file compression issue)
# {'name': 'Micah', 'message': 'proxy files?', 'time': '10:05'} {'name': 'Micah', 'message': 'proxy files?', 'time': '10:05'} yes-(suggesting a solution to the file transfer issue)
# {'name': 'Djones', 'message': 'one hour yes', 'time': '10:09'} {'name': 'Djones', 'message': 'one hour yes', 'time': '10:09'} yes-(correctly calculating the upload time)
# {'name': 'The Swayne', 'message': 'the speed is going to be limited by anything on the route.', 'time': '10:09'} {'name': 'The Swayne', 'message': 'the speed is going to be limited by anything on the route.', 'time': '10:09'} yes-(providing technical insight)
# {'name': 'Guacamolius', 'message': "per second. so it's minute", 'time': '10:19'} {'name': 'Guacamolius', 'message': "per second. so it's minute", 'time': '10:19'} yes-(correcting the previous calculation)
# {'name': 'd0lvl0', 'message': '~66.7minutes if fully capping internet, probably closer to ~80-90 minutes realistically', 'time': '10:20'} {'name': 'd0lvl0', 'message': '~66.7minutes if fully capping internet, probably closer to ~80-90 minutes realistically', 'time': '10:20'} yes-(providing a more accurate estimate of the upload time)
# {'name': 'shabbo84', 'message': '1hr 5 min @Destiny ', 'time': '10:29'} {'name': 'shabbo84', 'message': '1hr 5 min @Destiny ', 'time': '10:29'} yes-(providing the correct upload time estimate)
# {'name': 'LazyTurtle', 'message': '@destiny remote desktop?', 'time': '10:55'} {'name': 'LazyTurtle', 'message': '@destiny remote desktop?', 'time': '10:55'} yes-(suggesting a solution to the file transfer issue)
# {'name': 'Benjamin AVSTECH', 'message': 'Why are you making this complicated you don’t upload online for lossless quality you upload online optimize streaming files it’s 265', 'time': '10:58'} {'name': 'Benjamin AVSTECH', 'message': 'Why are you making this complicated you don’t upload online for lossless quality you upload online optimize streaming files it’s 265', 'time': '10:58'} yes-(providing a technical solution)
# {'name': 'Korean Bronze VI', 'message': '@Destiny Do you need to record in Pro ress compressed raw?', 'time': '11:01'} {'name': 'Korean Bronze VI', 'message': '@Destiny Do you need to record in Pro ress compressed raw?', 'time': '11:01'} yes-(suggesting a technical solution)
# {'name': 'not_a_real_name', 'message': 'Is his upload 1gb ? Usually its slower than download', 'time': '11:10'} {'name': 'not_a_real_name', 'message': 'Is his upload 1gb ? Usually its slower than download', 'time': '11:10'} yes-(providing technical insight)
# {'name': 'krinkerlsjhkg', 'message': 'this is literally what highspeed internet was made for', 'time': '11:20'} {'name': 'krinkerlsjhkg', 'message': 'this is literally what highspeed internet was made for', 'time': '11:20'} yes-(providing a technical solution)
# {'name': 'HippopotOfTea', 'message': 'Should be about 72 minutes.', 'time': '11:37'} {'name': 'HippopotOfTea', 'message': 'Should be about 72 minutes.', 'time': '11:37'} yes-(correctly calculating the upload time)
# {'name': 'Anthony Severi', 'message': 'gig connection is not both up and down speed', 'time': '11:42'} {'name': 'Anthony Severi', 'message': 'gig connection is not both up and down speed', 'time': '11:42'} yes-(providing technical insight)
# {'name': 'The Swayne', 'message': "August doesn't need to download the files. he can work from a vdi on your local network", 'time': '11:56'} {'name': 'The Swayne', 'message': "August doesn't need to download the files. he can work from a vdi on your local network", 'time': '11:56'} yes-(suggesting a technical solution)
# {'name': 'shabbo84', 'message': '@Destiny why would file size matter if he can start it in the evening and have it all in the morning however data there is', 'time': '12:17'} {'name': 'shabbo84', 'message': '@Destiny why would file size matter if he can start it in the evening and have it all in the morning however data there is', 'time': '12:17'} yes-(providing a technical solution)
# {'name': 'Benjamin AVSTECH', 'message': 'HEVC h.265 10000 or more constant bits per second', 'time': '12:51'} {'name': 'Benjamin AVSTECH', 'message': 'HEVC h.265 10000 or more constant bits per second', 'time': '12:51'} yes-(providing a technical solution)
# {'name': 'K B', 'message': '“Kim is another topic that comes up, with people wondering who she is and why she should be freed”. Chat summary hands down best feature', 'time': '12:52'} {'name': 'K B', 'message': '“Kim is another topic that comes up, with people wondering who she is and why she should be freed”. Chat summary hands down best feature', 'time': '12:52'} yes-(summarizing the chat discussion)
# {'name': 'The Swayne', 'message': 'yes', 'time': '13:03'} {'name': 'The Swayne', 'message': 'yes', 'time': '13:03'} yes-(serious response)
# {'name': 'zfrenchyz', 'message': 'Yes\\', 'time': '13:08'} {'name': 'zfrenchyz', 'message': 'Yes\\', 'time': '13:08'} yes-(serious response)
# {'name': 'The Swayne', 'message': "no it's not when set up correctly", 'time': '13:14'} {'name': 'The Swayne', 'message': "no it's not when set up correctly", 'time': '13:14'} yes-(providing technical insight)
# {'name': 'EnrageD', 'message': 'parsec is decent', 'time': '13:14'} {'name': 'EnrageD', 'message': 'parsec is decent', 'time': '13:14'} yes-(suggesting a technical solution)
# {'name': 'ImInfam0us', 'message': 'it would be laggy', 'time': '13:14'} {'name': 'ImInfam0us', 'message': 'it would be laggy', 'time': '13:14'} yes-(providing technical insight)
# {'name': 'Ali Ahmad', 'message': 'no ', 'time': '13:15'} {'name': 'Ali Ahmad', 'message': 'no ', 'time': '13:15'} yes-(providing technical insight)
# {'name': 'John moe', 'message': 'it would', 'time': '13:17'} {'name': 'John moe', 'message': 'it would', 'time': '13:17'} yes-(providing technical insight)
# {'name': 'Okay Duhuhud', 'message': 'maybe the tech has gotten better in current years', 'time': '13:19'} {'name': 'Okay Duhuhud', 'message': 'maybe the tech has gotten better in current years', 'time': '13:19'} yes-(providing technical insight)
# {'name': 'Bryan Conrad', 'message': 'probably fine on your gigabit fiber', 'time': '13:21'} {'name': 'Bryan Conrad', 'message': 'probably fine on your gigabit fiber', 'time': '13:21'} yes-(providing technical insight)
# {'name': 'omishalov', 'message': 'moonlight', 'time': '13:25'} {'name': 'omishalov', 'message': 'moonlight', 'time': '13:25'} yes-(suggesting a technical solution)
# {'name': 'MikeTheDriver', 'message': 'parsec', 'time': '13:26'} {'name': 'MikeTheDriver', 'message': 'parsec', 'time': '13:26'} yes-(suggesting a technical solution)
# {'name': 'Rahul Puppala', 'message': 'i use a vdi for programming its preety good latency maybe 15ms', 'time': '13:27'} {'name': 'Rahul Puppala', 'message': 'i use a vdi for programming its preety good latency maybe 15ms', 'time': '13:27'} yes-(providing technical insight)
# {'name': 'Crisis Ostrich', 'message': 'make a copy and mail it to him', 'time': '13:28'} {'name': 'Crisis Ostrich', 'message': 'make a copy and mail it to him', 'time': '13:28'} yes-(suggesting a technical solution)
# {'name': 'HippopotOfTea', 'message': 'yeah, that sounds like a nightmare', 'time': '13:30'} {'name': 'HippopotOfTea', 'message': 'yeah, that sounds like a nightmare', 'time': '13:30'} yes-(providing technical insight)
# {'name': 'serengeor', 'message': 'if the editing pc is shit, but then why are you editing on a shit pc', 'time': '13:30'} {'name': 'serengeor', 'message': 'if the editing pc is shit, but then why are you editing on a shit pc', 'time': '13:30'} yes-(providing technical insight)
# {'name': 'Micah', 'message': 'I have no idea. How bad would it be with proxy files?', 'time': '13:30'} {'name': 'Micah', 'message': 'I have no idea. How bad would it be with proxy files?', 'time': '13:30'} yes-(asking for more information)
# {'name': 'Micairinos', 'message': '@Destiny, we work with "Parsec" in an architecture firm and we do video and rendering remotely. Could be an easy solution', 'time': '13:31'} {'name': 'Micairinos', 'message': '@Destiny, we work with "Parsec" in an architecture firm and we do video and rendering remotely. Could be an easy solution', 'time': '13:31'} yes-(suggesting a technical solution)
# {'name': 'cgiacona', 'message': "@Destiny It wouldn't be laggy, but it wouldn't be good for color critical work.", 'time': '13:32'} {'name': 'cgiacona', 'message': "@Destiny It wouldn't be laggy, but it wouldn't be good for color critical work.", 'time': '13:32'} yes-(providing technical insight)
# {'name': 'Twitch Reacts', 'message': 'I can do Inferno run on OSRS with parsec so yess', 'time': '13:33'} {'name': 'Twitch Reacts', 'message': 'I can do Inferno run on OSRS with parsec so yess', 'time': '13:33'} yes-(providing technical insight)
# {'name': 'zfrenchyz', 'message': 'Teradici is a good remote desktop app. Professional one, and very low lag. I use it for wfh', 'time': '13:39'} {'name': 'zfrenchyz', 'message': 'Teradici is a good remote desktop app. Professional one, and very low lag. I use it for wfh', 'time': '13:39'} yes-(suggesting a technical solution)
# {'name': 'Calleronline1', 'message': 'no lag', 'time': '13:39'} {'name': 'Calleronline1', 'message': 'no lag', 'time': '13:39'} yes-(providing technical insight)
# {'name': 'DrenGod', 'message': 'use parsec ', 'time': '13:43'} {'name': 'DrenGod', 'message': 'use parsec ', 'time': '13:43'} yes-(suggesting a technical solution)
# {'name': 'Zachary Isom', 'message': "You can remote into a computer an game, video editing would be easier because you're not transmitting much data.", 'time': '13:45'} {'name': 'Zachary Isom', 'message': "You can remote into a computer an game, video editing would be easier because you're not transmitting much data.", 'time': '13:45'} yes-(providing technical insight)
# {'name': 'Korean Bronze VI', 'message': 'Would probably be inpractical from Australia, but alot of my coworkers edit reality shows remotely', 'time': '13:52'} {'name': 'Korean Bronze VI', 'message': 'Would probably be inpractical from Australia, but alot of my coworkers edit reality shows remotely', 'time': '13:52'} yes-(providing technical insight)
# {'name': 'Bryan Conrad', 'message': "it's actually a good idea but he won't listen", 'time': '13:56'} {'name': 'Bryan Conrad', 'message': "it's actually a good idea but he won't listen", 'time': '13:56'} yes-(providing technical insight)
# {'name': 'The Swayne', 'message': 'we do it at my job all the time for people all over the world', 'time': '14:00'} {'name': 'The Swayne', 'message': 'we do it at my job all the time for people all over the world', 'time': '14:00'} yes-(providing technical insight)
# {'name': 'Chipa', 'message': "With the right configuration, it's totally doable. Even LTT put a video out about OTA live editing...although their case is super niche....it wouldn't be impossible...", 'time': '14:00'} {'name': 'Chipa', 'message': "With the right configuration, it's totally doable. Even LTT put a video out about OTA live editing...although their case is super niche....it wouldn't be impossible...", 'time': '14:00'} yes-(providing technical insight)
# {'name': 'Zachary Isom', 'message': "You're just transmitting the images on the screen and occasional inputs. The latency would be almost zero", 'time': '14:09'} {'name': 'Zachary Isom', 'message': "You're just transmitting the images on the screen and occasional inputs. The latency would be almost zero", 'time': '14:09'} yes-(providing technical insight)
# {'name': 'shabbo84', 'message': '@Bryan Conrad bandwith has nothing to do with Austraila to US and back input lag, it would be pain to edit stuff.. each keypress has 200-300 ms lag', 'time': '14:14'} {'name': 'shabbo84', 'message': '@Bryan Conrad bandwith has nothing to do with Austraila to US and back input lag, it would be pain to edit stuff.. each keypress has 200-300 ms lag', 'time': '14:14'} yes-(providing technical insight)
# {'name': 'HippopotOfTea', 'message': 'possibly he could do a rough edit on a remote system and then pull over a smaller file for the finishing touches', 'time': '14:15'} {'name': 'HippopotOfTea', 'message': 'possibly he could do a rough edit on a remote system and then pull over a smaller file for the finishing touches', 'time': '14:15'} yes-(suggesting a technical solution)
# {'name': 'K B', 'message': 'I feel like he’s over complicating this', 'time': '14:15'} {'name': 'K B', 'message': 'I feel like he’s over complicating this', 'time': '14:15'} yes-(providing technical insight)
# {'name': 'Guacamolius', 'message': 'at this point just ship him the physical drive and be done', 'time': '14:39'} {'name': 'Guacamolius', 'message': 'at this point just ship him the physical drive and be done', 'time': '14:39'} yes-(suggesting a technical solution)
# {'name': 'Michael', 'message': 'just use proxies?', 'time': '14:40'} {'name': 'Michael', 'message': 'just use proxies?', 'time': '14:40'} yes-(suggesting a technical solution)
# {'name': 'Zachary Isom', 'message': "Almost all editing is done remotely anyway because the file you're editing is stored remotely.", 'time': '14:45'} {'name': 'Zachary Isom', 'message': "Almost all editing is done remotely anyway because the file you're editing is stored remotely.", 'time': '14:45'} yes-(a serious suggestion about remote editing)
# {'name': 'Magni Þór Björnsson', 'message': "Why doesn't he just send the files on drives, with UPS? Faster transfer speed potentially.", 'time': '14:55'} {'name': 'Magni Þór Björnsson', 'message': "Why doesn't he just send the files on drives, with UPS? Faster transfer speed potentially.", 'time': '14:55'} yes-(a serious suggestion about using physical drives)
# {'name': 'WistfulBlade', 'message': 'Use a site to site vpn.', 'time': '15:01'} {'name': 'WistfulBlade', 'message': 'Use a site to site vpn.', 'time': '15:01'} yes-(a serious suggestion about using a VPN)
# {'name': ' The RedDawn Batman', 'message': ' @Destiny did you see the just stopped oil group just damaged Stonehenge', 'time': '15:10'} {'name': ' The RedDawn Batman', 'message': ' @Destiny did you see the just stopped oil group just damaged Stonehenge', 'time': '15:10'} yes-(a question about Stonehenge being damaged)
# {'name': 'Conor', 'message': '@Destiny Start reading your WW1 book before you get distracted.', 'time': '15:10'} {'name': 'Conor', 'message': '@Destiny Start reading your WW1 book before you get distracted.', 'time': '15:10'} yes-(a suggestion for Destiny to read a book)
# {'name': 'Zachary Isom', 'message': "Most video editing machines don't have 600TB of storage. They have network storage they access.", 'time': '15:16'} {'name': 'Zachary Isom', 'message': "Most video editing machines don't have 600TB of storage. They have network storage they access.", 'time': '15:16'} yes-(a serious point about video editing storage)
# {'name': 'ScruffMcDuff', 'message': 'yoo destiny how do you feel about stefan molyneux and his banning?', 'time': '15:17'} {'name': 'ScruffMcDuff', 'message': 'yoo destiny how do you feel about stefan molyneux and his banning?', 'time': '15:17'} yes-(a question about Destiny's thoughts on Stefan Molyneux)
# {'name': 'K B', 'message': 'Just tell him to fly back, edit the video, and then return to Australia. It’s not that hard. ', 'time': '15:25'} {'name': 'K B', 'message': 'Just tell him to fly back, edit the video, and then return to Australia. It’s not that hard. ', 'time': '15:25'} yes-(a serious suggestion about having the editor fly back and forth)
# {'name': 'hujiko44745278184', 'message': 'orange paint', 'time': '15:31'} {'name': 'hujiko44745278184', 'message': 'orange paint', 'time': '15:31'} yes-(a mention of orange paint)
# {'name': 'Korean Bronze VI', 'message': '@Destiny Are you filming in 6k open gate? Is that realy necesary for youtube?', 'time': '15:36'} {'name': 'Korean Bronze VI', 'message': '@Destiny Are you filming in 6k open gate? Is that realy necesary for youtube?', 'time': '15:36'} yes-(a question about filming in 6k)
# {'name': 'Dennis S.', 'message': 'Just finished listening to your JBP debate. He’s gone insane these past few years. ', 'time': '15:38'} {'name': 'Dennis S.', 'message': 'Just finished listening to your JBP debate. He’s gone insane these past few years. ', 'time': '15:38'} yes-(a comment about a JBP debate)
# {'name': 'Benjamin', 'message': 'they painted them ', 'time': '15:38'} {'name': 'Benjamin', 'message': 'they painted them ', 'time': '15:38'} yes-(a statement that they painted the stones)
# {'name': 'hujiko44745278184', 'message': 'they defaced it', 'time': '15:40'} {'name': 'hujiko44745278184', 'message': 'they defaced it', 'time': '15:40'} yes-(a statement that they defaced Stonehenge)
# {'name': 'Ali Iftihkar', 'message': 'they painted it orange', 'time': '15:41'} {'name': 'Ali Iftihkar', 'message': 'they painted it orange', 'time': '15:41'} yes-(a statement that they painted it orange)
# {'name': 'Benjamin', 'message': 'they painted them orange', 'time': '15:44'} {'name': 'Benjamin', 'message': 'they painted them orange', 'time': '15:44'} yes-(a statement that they painted the stones orange)
# {'name': 'Anonymous Account', 'message': 'They painted them orange', 'time': '15:45'} {'name': 'Anonymous Account', 'message': 'They painted them orange', 'time': '15:45'} yes-(a statement that they painted the stones orange)
# {'name': 'Judge', 'message': 'Andrew Wilson debating as pro Biden with Rob Noerr debating pro Trump was pretty fun to watch. Andrew won.', 'time': '15:46'} {'name': 'Judge', 'message': 'Andrew Wilson debating as pro Biden with Rob Noerr debating pro Trump was pretty fun to watch. Andrew won.', 'time': '15:46'} yes-(a comment about a political debate)
# {'name': 'Jean-Pierre Jacques', 'message': 'worst case, just UPS some sd cards to your editor', 'time': '15:49'} {'name': 'Jean-Pierre Jacques', 'message': 'worst case, just UPS some sd cards to your editor', 'time': '15:49'} yes-(a serious suggestion about using SD cards)
# {'name': 'Joseph', 'message': 'How will damaging 5k year old stones stop oil?', 'time': '15:51'} {'name': 'Joseph', 'message': 'How will damaging 5k year old stones stop oil?', 'time': '15:51'} yes-(a question about how damaging Stonehenge will stop oil)
# {'name': 'Kev Dawg', 'message': 'they did a really bad job too. normal spraypaint can woulda been way more effective lol.', 'time': '15:55'} {'name': 'Kev Dawg', 'message': 'they did a really bad job too. normal spraypaint can woulda been way more effective lol.', 'time': '15:55'} yes-(a comment about the poor job of painting the stones)
# {'name': 'Pedro 50', 'message': 'The stones must be aligned why they like this', 'time': '15:55'} {'name': 'Pedro 50', 'message': 'The stones must be aligned why they like this', 'time': '15:55'} yes-(a comment about the stones needing to be aligned)
# {'name': 'Horvath Sogranfume', 'message': 'the used powder', 'time': '15:59'} {'name': 'Horvath Sogranfume', 'message': 'the used powder', 'time': '15:59'} yes-(a statement that they used powder)
# {'name': 'not_a_real_name', 'message': 'Just get him to tell you what buttons to push to edit', 'time': '16:06'} {'name': 'not_a_real_name', 'message': 'Just get him to tell you what buttons to push to edit', 'time': '16:06'} yes-(a serious suggestion about having the editor tell Destiny what buttons to push)
# {'name': 'toxyie_', 'message': 'how did bridges go?', 'time': '16:13'} {'name': 'toxyie_', 'message': 'how did bridges go?', 'time': '16:13'} yes-(a question about how the bridges went)
# {'name': 'tired of my cinicism', 'message': 'turkey tom stream?', 'time': '16:13'} {'name': 'tired of my cinicism', 'message': 'turkey tom stream?', 'time': '16:13'} yes-(a question about a Turkey Tom stream)
# {'name': 'Давидка С.', 'message': 'what chat is he reading', 'time': '16:14'} {'name': 'Давидка С.', 'message': 'what chat is he reading', 'time': '16:14'} yes-(a question about what chat Destiny is reading)
# {'name': 'WookieWarrior', 'message': 'the relfection from his ring, goated', 'time': '16:16'} {'name': 'WookieWarrior', 'message': 'the relfection from his ring, goated', 'time': '16:16'} yes-(a comment about the reflection from Destiny's ring)
# {'name': 'undesirable🏳️\u200d🌈', 'message': "it's shiny asl", 'time': '16:17'} {'name': 'undesirable🏳️\u200d🌈', 'message': "it's shiny asl", 'time': '16:17'} yes-(a comment about the ring being shiny)
# {'name': 'FROchinima', 'message': 'the glare i guess', 'time': '16:20'} {'name': 'FROchinima', 'message': 'the glare i guess', 'time': '16:20'} yes-(a comment about the glare from the ring)
# {'name': 'E Martinez', 'message': 'its shiny and expensive', 'time': '16:22'} {'name': 'E Martinez', 'message': 'its shiny and expensive', 'time': '16:22'} yes-(a comment about the ring being shiny and expensive)
# {'name': 'HarpoCoatl', 'message': 'the glint from the ring', 'time': '16:23'} {'name': 'HarpoCoatl', 'message': 'the glint from the ring', 'time': '16:23'} yes-(a comment about the glint from the ring)
# {'name': 'Marrsund', 'message': 'no joke, just bling', 'time': '16:25'} {'name': 'Marrsund', 'message': 'no joke, just bling', 'time': '16:25'} yes-(a comment that it's just shiny, no joke)
# {'name': 'Anthony Severi', 'message': 'do a speed test.. or send a test upload to him...so you can get a real world idea of upload time', 'time': '16:26'} {'name': 'Anthony Severi', 'message': 'do a speed test.. or send a test upload to him...so you can get a real world idea of upload time', 'time': '16:26'} yes-(a suggestion to do a speed test or test upload)
# {'name': 'Nightbot', 'message': 'He does read youtube chat, and he will perma ban you without warning. If you highlight him with something dumb, we can not save you.', 'time': '16:26'} {'name': 'Nightbot', 'message': 'He does read youtube chat, and he will perma ban you without warning. If you highlight him with something dumb, we can not save you.', 'time': '16:26'} yes-(a warning about Destiny banning people in YouTube chat)
# {'name': 'Vanalovan', 'message': 'HistorySpeaks is having a an I/P debate right now on spaces I think', 'time': '16:27'} {'name': 'Vanalovan', 'message': 'HistorySpeaks is having a an I/P debate right now on spaces I think', 'time': '16:27'} yes-(a mention of a debate happening on Spaces)
# {'name': 'Anonymous Account', 'message': "I think it's just light bouncing off his golden ring", 'time': '16:27'} {'name': 'Anonymous Account', 'message': "I think it's just light bouncing off his golden ring", 'time': '16:27'} yes-(an explanation that it's just light bouncing off the ring)
# {'name': 'Kev Dawg', 'message': 'he blangin', 'time': '16:28'} {'name': 'Kev Dawg', 'message': 'he blangin', 'time': '16:28'} yes-(a comment that Destiny is "blangin")
# {'name': 'iamsofired', 'message': 'just goild', 'time': '16:28'} {'name': 'iamsofired', 'message': 'just goild', 'time': '16:28'} yes-(a comment that it's just gold)
# {'name': 'Benjamin', 'message': 'There is no way that "just stop oil" isnt funded by big oil companies to make their image better', 'time': '16:30'} {'name': 'Benjamin', 'message': 'There is no way that "just stop oil" isnt funded by big oil companies to make their image better', 'time': '16:30'} yes-(a comment about Just Stop Oil potentially being funded by oil companies)
# {'name': 'Fred DeGreeff', 'message': 'They put smoke flairs directly against he stone', 'time': '16:35'} {'name': 'Fred DeGreeff', 'message': 'They put smoke flairs directly against he stone', 'time': '16:35'} yes-(a statement about them using smoke flares against the stones)
# {'name': 'Vanalovan', 'message': 'With an Israeli phd', 'time': '16:36'} {'name': 'Vanalovan', 'message': 'With an Israeli phd', 'time': '16:36'} yes-(a mention of an Israeli PhD)
# {'name': 'Tanisha Moore', 'message': "Just the light flashing in it. Isn't that funny.", 'time': '16:38'} {'name': 'Tanisha Moore', 'message': "Just the light flashing in it. Isn't that funny.", 'time': '16:38'} yes-(an explanation that it's just the light flashing in the ring)
# {'name': 'alpha 🏳️\u200d🌈', 'message': 'he flexin and flashin', 'time': '16:40'} {'name': 'alpha 🏳️\u200d🌈', 'message': 'he flexin and flashin', 'time': '16:40'} yes-(a comment that Destiny is flexing and flashing)
# {'name': 'K B', 'message': 'JSO makes me want to use more oil to spite them. ', 'time': '16:43'} {'name': 'K B', 'message': 'JSO makes me want to use more oil to spite them. ', 'time': '16:43'} yes-(a comment about wanting to use more oil to spite Just Stop Oil)
# {'name': 'Take A Gander', 'message': 'Shining Ahhhhh', 'time': '16:46'} {'name': 'Take A Gander', 'message': 'Shining Ahhhhh', 'time': '16:46'} yes-(a comment about the ring shining)
# {'name': 'woahitskyle', 'message': 'people at chipotle film workers because there was a tiktok trend saying they make the food better if it goes online', 'time': '16:46'} {'name': 'woahitskyle', 'message': 'people at chipotle film workers because there was a tiktok trend saying they make the food better if it goes online', 'time': '16:46'} yes-(a comment about a TikTok trend of filming Chipotle workers)
# {'name': 'Johan Nilsson', 'message': 'Sorry I was note paying attention. Was the issue that upload time to Australia was to long?', 'time': '16:52'} {'name': 'Johan Nilsson', 'message': 'Sorry I was note paying attention. Was the issue that upload time to Australia was to long?', 'time': '16:52'} yes-(a question about the issue being long upload times to Australia)
# {'name': 'undesirable🏳️\u200d🌈', 'message': "he's allowing him the light of his ring and the wagey better be grateful", 'time': '16:55'} {'name': 'undesirable🏳️\u200d🌈', 'message': "he's allowing him the light of his ring and the wagey better be grateful", 'time': '16:55'} yes-(a comment about Destiny allowing the light of his ring)
# {'name': 'Molari', 'message': 'No Elden Ring DLC?', 'time': '16:57'} {'name': 'Molari', 'message': 'No Elden Ring DLC?', 'time': '16:57'} yes-(a question about Elden Ring DLC)
# {'name': 'E Martinez', 'message': 'shiny things are usually expensive,', 'time': '16:58'} {'name': 'E Martinez', 'message': 'shiny things are usually expensive,', 'time': '16:58'} yes-(a comment that shiny things are usually expensive)
# {'name': 'Давидка С.', 'message': 'but with who is he talking to?', 'time': '16:59'} {'name': 'Давидка С.', 'message': 'but with who is he talking to?', 'time': '16:59'} yes-(a question about who Destiny is talking to)
# {'name': 'Mac Osiem', 'message': 'Elden Ring DLC in 2 days', 'time': '16:59'} {'name': 'Mac Osiem', 'message': 'Elden Ring DLC in 2 days', 'time': '16:59'} yes-(a mention of Elden Ring DLC coming out in 2 days)
# {'name': 'Pondy', 'message': 'elden ring dlc bitch', 'time': '17:01'} {'name': 'Pondy', 'message': 'elden ring dlc bitch', 'time': '17:01'} yes-(a message saying "Elden Ring DLC in 2 days")
# {'name': 'Guacamolius', 'message': "at this point, we'll take factorio. this needs to stop.", 'time': '17:03'} {'name': 'Guacamolius', 'message': "at this point, we'll take factorio. this needs to stop.", 'time': '17:03'} yes-(a message saying they'll take Factorio at this point)
# {'name': 'Benjamin', 'message': 'HE WAS PAYING WITH EXPOSURE', 'time': '17:04'} {'name': 'Benjamin', 'message': 'HE WAS PAYING WITH EXPOSURE', 'time': '17:04'} yes-(a message about Destiny paying with exposure)
# {'name': 'Matthew', 'message': 'Elden ring tomorrow ', 'time': '17:04'} {'name': 'Matthew', 'message': 'Elden ring tomorrow ', 'time': '17:04'} yes-(a message about Elden Ring DLC coming out tomorrow)
# {'name': 'Edel Salazar', 'message': 'elden ring dlc coming out tomorrow', 'time': '17:05'} {'name': 'Edel Salazar', 'message': 'elden ring dlc coming out tomorrow', 'time': '17:05'} yes-(a message about Elden Ring DLC coming out tomorrow)
# {'name': 'Donquixote 101', 'message': "It'll be way longer than a few weeks lmao.", 'time': '17:07'} {'name': 'Donquixote 101', 'message': "It'll be way longer than a few weeks lmao.", 'time': '17:07'} yes-(a message saying it'll be way longer than a few weeks)
# {'name': 'Dennis S.', 'message': 'What the hell is a factorio?', 'time': '17:08'} {'name': 'Dennis S.', 'message': 'What the hell is a factorio?', 'time': '17:08'} yes-(a question about what Factorio is)
# {'name': 'Radium1993', 'message': 'What about the new elden ring dlc?', 'time': '17:09'} {'name': 'Radium1993', 'message': 'What about the new elden ring dlc?', 'time': '17:09'} yes-(a question about the new Elden Ring DLC)
# {'name': 'Eric', 'message': "Man's getting back into gaming?", 'time': '17:09'} {'name': 'Eric', 'message': "Man's getting back into gaming?", 'time': '17:09'} yes-(a message about Destiny getting back into gaming)
# {'name': 'Gabreyes093', 'message': '@Destiny do music streams. Jam with Lily', 'time': '17:09'} {'name': 'Gabreyes093', 'message': '@Destiny do music streams. Jam with Lily', 'time': '17:09'} yes-(a suggestion for Destiny to do music streams and jam with Lily)
# {'name': 'Edel Salazar', 'message': 'elden ring', 'time': '17:12'} {'name': 'Edel Salazar', 'message': 'elden ring', 'time': '17:12'} yes-(a message about Elden Ring)
# {'name': 'Louiso', 'message': 'WAIT ELEDEN RING TOMORROW???', 'time': '17:15'} {'name': 'Louiso', 'message': 'WAIT ELEDEN RING TOMORROW???', 'time': '17:15'} yes-(a question about the new Elden Ring DLC coming out tomorrow)
# {'name': 'xavcim', 'message': 'PLAY ELDEN RING STEVEN or bg3', 'time': '17:16'} {'name': 'xavcim', 'message': 'PLAY ELDEN RING STEVEN or bg3', 'time': '17:16'} yes-(a suggestion for Destiny to play Elden Ring or BG3)
# {'name': '1dwkjr', 'message': 'the ai chat summaries are hilarious', 'time': '17:18'} {'name': '1dwkjr', 'message': 'the ai chat summaries are hilarious', 'time': '17:18'} yes-(a comment about the AI chat summaries being hilarious)
# {'name': 'Guacamolius', 'message': 'what is lil bro watching', 'time': '17:26'} {'name': 'Guacamolius', 'message': 'what is lil bro watching', 'time': '17:26'} yes-(a question about what Destiny is watching)
# {'name': 'blubbins', 'message': '@Destiny do ONE leeg match if your gonna do another factorio run.', 'time': '17:26'} {'name': 'blubbins', 'message': '@Destiny do ONE leeg match if your gonna do another factorio run.', 'time': '17:26'} yes-(a suggestion for Destiny to play one League match if he's going to do another Factorio run)
# {'name': 'Vojtěch Kuchař', 'message': 'Lmao hearing Czech', 'time': '17:27'} {'name': 'Vojtěch Kuchař', 'message': 'Lmao hearing Czech', 'time': '17:27'} yes-(a message about hearing Czech)
# {'name': 'Conor', 'message': '@Destiny Play MGS3 !!!', 'time': '17:28'} {'name': 'Conor', 'message': '@Destiny Play MGS3 !!!', 'time': '17:28'} yes-(a suggestion for Destiny to play MGS3)
# {'name': 'Kev Dawg', 'message': 'idk why destiny is excited to make another mid factory', 'time': '17:29'} {'name': 'Kev Dawg', 'message': 'idk why destiny is excited to make another mid factory', 'time': '17:29'} yes-(a message saying they don't know why Destiny is excited for another Factorio run)
# {'name': 'Jusifer', 'message': '@Destiny have you played elden ring? Will you play the dlc thats coming in 2 days?', 'time': '18:29'} {'name': 'Jusifer', 'message': '@Destiny have you played elden ring? Will you play the dlc thats coming in 2 days?', 'time': '18:29'} yes-(asking about Destiny's gaming plans)
# {'name': 'Edel Salazar', 'message': 'elden ring dlc tomorrow', 'time': '18:41'} {'name': 'Edel Salazar', 'message': 'elden ring dlc tomorrow', 'time': '18:41'} yes-(informing about Elden Ring DLC)
# {'name': 'Давидка С.', 'message': 'he is clearly responding and reading something. what is he reading? from where??', 'time': '19:07'} {'name': 'Давидка С.', 'message': 'he is clearly responding and reading something. what is he reading? from where??', 'time': '19:07'} yes-(asking what Destiny is reading)
# {'name': 'אביתר שטראוס', 'message': 'Did you send condolences to YMS? his friend died this week', 'time': '19:23'} {'name': 'אביתר שטראוס', 'message': 'Did you send condolences to YMS? his friend died this week', 'time': '19:23'} yes-(asking about Destiny's condolences)
# {'name': 'woahitskyle', 'message': "apparently you need partner so they can't make threats about other partners lol", 'time': '19:39'} {'name': 'woahitskyle', 'message': "apparently you need partner so they can't make threats about other partners lol", 'time': '19:39'} yes-(observation about Twitch partner requirements)
# {'name': 'HippopotOfTea', 'message': 'He mostly reads DDG and Kick chat, but does also look at YT chat sometimes when he wants to read the best chat', 'time': '19:39'} {'name': 'HippopotOfTea', 'message': 'He mostly reads DDG and Kick chat, but does also look at YT chat sometimes when he wants to read the best chat', 'time': '19:39'} yes-(informing about Destiny's chat reading habits)
# {'name': 'K B', 'message': 'Wait is right to left text a global setting? I for sure would’ve thought it would just be on the user’s side', 'time': '20:49'} {'name': 'K B', 'message': 'Wait is right to left text a global setting? I for sure would’ve thought it would just be on the user’s side', 'time': '20:49'} yes-(question about text direction)
# {'name': 'Logic Bombs', 'message': 'true, its sad and boring', 'time': '20:52'} {'name': 'Logic Bombs', 'message': 'true, its sad and boring', 'time': '20:52'} yes-(observation about Twitch political content)
# {'name': 'Benjamin', 'message': '@Destiny when is your podcast with tectone ? ', 'time': '21:07'} {'name': 'Benjamin', 'message': '@Destiny when is your podcast with tectone ? ', 'time': '21:07'} yes-(question about Destiny's podcast plans)
# {'name': 'HippopotOfTea', 'message': 'Disagree, they are clout streamers first and politics is only an aesthetic!', 'time': '21:11'} {'name': 'HippopotOfTea', 'message': 'Disagree, they are clout streamers first and politics is only an aesthetic!', 'time': '21:11'} yes-(disagreement with previous observation)
# {'name': 'Logic Bombs', 'message': "true why tf aren't there interesting panels and shit", 'time': '21:18'} {'name': 'Logic Bombs', 'message': "true why tf aren't there interesting panels and shit", 'time': '21:18'} yes-(observation about lack of Twitch political content)
# {'name': 'Fred DeGreeff', 'message': '@Destiny Dr. K and asmon defend you and otk seems to be on your side', 'time': '21:39'} {'name': 'Fred DeGreeff', 'message': '@Destiny Dr. K and asmon defend you and otk seems to be on your side', 'time': '21:39'} yes-(observation about Destiny's supporters)
# {'name': 'Fun Things', 'message': 'You should bring Lily on Anything Else!! Based on your old videos I think it would be a good fit', 'time': '21:47'} {'name': 'Fun Things', 'message': 'You should bring Lily on Anything Else!! Based on your old videos I think it would be a good fit', 'time': '21:47'} yes-(suggestion about Destiny's content)
# ...
# {'name': 'Charles Aviles', 'message': 'HOLY', 'time': '1:58:49'} {'name': 'Charles Aviles', 'message': 'HOLY', 'time': '1:58:49'} yes-(shocked reaction to the story)
# {'name': 'Big Tex', 'message': 'LMAOOOOOOOOOOO', 'time': '1:58:49'} {'name': 'Big Tex', 'message': 'LMAOOOOOOOOOOO', 'time': '1:58:49'} yes-(amused reaction to the story)
# {'name': 'J B', 'message': 'Knew it ', 'time': '1:58:50'} {'name': 'J B', 'message': 'Knew it ', 'time': '1:58:50'} yes-(anticipating the story)
# {'name': 'Pea Soup', 'message': 'Lmao', 'time': '1:58:50'} {'name': 'Pea Soup', 'message': 'Lmao', 'time': '1:58:50'} yes-(amused reaction to the story)
# {'name': 'Benjamin', 'message': ':_destinyFeelsGood: CINEMA ', 'time': '1:58:51'} {'name': 'Benjamin', 'message': ':_destinyFeelsGood: CINEMA ', 'time': '1:58:51'} yes-(positive reaction to the story)
# {'name': 'Raiders Cat🕶🐢', 'message': ':_destinyFeelsWeird:', 'time': '1:58:52'} {'name': 'Raiders Cat🕶🐢', 'message': ':_destinyFeelsWeird:', 'time': '1:58:52'} yes-(confused reaction to the story)
# {'name': 'Ozymandias', 'message': 'AYOOOOOO', 'time': '1:58:52'} {'name': 'Ozymandias', 'message': 'AYOOOOOO', 'time': '1:58:52'} yes-(surprised reaction to the story)
# {'name': 'LongBoy420', 'message': 'WAIT THAT WAS GOOD ', 'time': '1:58:53'} {'name': 'LongBoy420', 'message': 'WAIT THAT WAS GOOD ', 'time': '1:58:53'} yes-(positive reaction to the story)
# {'name': 'Tim R', 'message': 'KEK', 'time': '1:58:53'} {'name': 'Tim R', 'message': 'KEK', 'time': '1:58:53'} yes-(amused reaction to the story)
# {'name': 'VoidPlague_', 'message': 'LMAO', 'time': '1:58:53'} {'name': 'VoidPlague_', 'message': 'LMAO', 'time': '1:58:53'} yes-(amused reaction to the story)
# {'name': 'Belavik', 'message': 'HOLY', 'time': '1:58:54'} {'name': 'Belavik', 'message': 'HOLY', 'time': '1:58:54'} yes-(shocked reaction to the story)
# {'name': 'EC', 'message': 'AYOO', 'time': '1:58:54'} {'name': 'EC', 'message': 'AYOO', 'time': '1:58:54'} yes-(surprised reaction to the story)
# {'name': 'Big Aaron', 'message': 'lmao', 'time': '1:58:54'} {'name': 'Big Aaron', 'message': 'lmao', 'time': '1:58:54'} yes-(amused reaction to the story)
# {'name': 'Na~oodles', 'message': 'lmaooo', 'time': '1:58:54'} {'name': 'Na~oodles', 'message': 'lmaooo', 'time': '1:58:54'} yes-(amused reaction to the story)
# {'name': 'Ronny', 'message': 'WHOAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA', 'time': '1:58:55'} {'name': 'Ronny', 'message': 'WHOAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA', 'time': '1:58:55'} yes-(shocked reaction to the story)
# {'name': 'j !', 'message': ':_destinyOMEGALUL::_destinyOMEGALUL:', 'time': '1:58:55'} {'name': 'j !', 'message': ':_destinyOMEGALUL::_destinyOMEGALUL:', 'time': '1:58:55'} yes-(mocking reaction to the story)
# {'name': 'BefuddledBacon', 'message': ':_destinyOMEGALUL:', 'time': '1:58:55'} {'name': 'BefuddledBacon', 'message': ':_destinyOMEGALUL:', 'time': '1:58:55'} yes-(mocking reaction to the story)
# {'name': 'Justin Dillon', 'message': ':face-orange-biting-nails::face-orange-biting-nails::face-orange-biting-nails:', 'time': '1:58:56'} {'name': 'Justin Dillon', 'message': ':face-orange-biting-nails::face-orange-biting-nails::face-orange-biting-nails:', 'time': '1:58:56'} yes-(concerned reaction to the story)
# {'name': 'Leon Kingsley', 'message': 'HAHAHA', 'time': '1:58:56'} {'name': 'Leon Kingsley', 'message': 'HAHAHA', 'time': '1:58:56'} yes-(amused reaction to the story)
# {'name': 'Tort', 'message': 'HOOOLY', 'time': '1:58:57'} {'name': 'Tort', 'message': 'HOOOLY', 'time': '1:58:57'} yes-(shocked reaction to the story)
# {'name': 'MarcusRojo', 'message': 'THEY NOT LIKE DESTINY', 'time': '1:58:57'} {'name': 'MarcusRojo', 'message': 'THEY NOT LIKE DESTINY', 'time': '1:58:57'} yes-(amused reaction to the story)
# {'name': 'Spiero', 'message': 'AYOOOOO', 'time': '1:58:59'} {'name': 'Spiero', 'message': 'AYOOOOO', 'time': '1:58:59'} yes-(surprised reaction to the story)
# {'name': 'shoo', 'message': 'OMEGALUL ', 'time': '1:59:00'} {'name': 'shoo', 'message': 'OMEGALUL ', 'time': '1:59:00'} yes-(amused reaction to the story)
# {'name': 'Luckytime', 'message': 'whiplash', 'time': '1:59:00'} {'name': 'Luckytime', 'message': 'whiplash', 'time': '1:59:00'} yes-(positive reaction to the story)
# {'name': 'Santiago Navas', 'message': ':loudly_crying_face:', 'time': '1:59:00'} {'name': 'Santiago Navas', 'message': ':loudly_crying_face:', 'time': '1:59:00'} yes-(sad reaction to the story)
# {'name': 'Caboodiest Mai', 'message': 'lol what is that fit xD', 'time': '1:59:01'} {'name': 'Caboodiest Mai', 'message': 'lol what is that fit xD', 'time': '1:59:01'} yes-(amused reaction to the story)
# {'name': 'grahamcracker', 'message': 'bars', 'time': '1:59:01'} {'name': 'grahamcracker', 'message': 'bars', 'time': '1:59:01'} yes-(positive reaction to the story)
# {'name': 'explosivez 10', 'message': 'Ooo the janitor knew he was a criminal ', 'time': '1:59:01'} {'name': 'explosivez 10', 'message': 'Ooo the janitor knew he was a criminal ', 'time': '1:59:01'} yes-(positive reaction to the story)
# {'name': 'Ondorichan', 'message': 'lmao', 'time': '1:59:02'} {'name': 'Ondorichan', 'message': 'lmao', 'time': '1:59:02'} yes-(amused reaction to the story)
# {'name': 'Nick_Jr.', 'message': 'classic', 'time': '1:59:02'} {'name': 'Nick_Jr.', 'message': 'classic', 'time': '1:59:02'} yes-(positive reaction to the story)
# {'name': 'Jace Santibata', 'message': 'OMEGALUL', 'time': '1:59:03'} {'name': 'Jace Santibata', 'message': 'OMEGALUL', 'time': '1:59:03'} yes-(amused reaction to the story)
# {'name': 'Otoriyo!', 'message': 'AYO', 'time': '1:59:03'} {'name': 'Otoriyo!', 'message': 'AYO', 'time': '1:59:03'} yes-(surprised reaction to the story)
# {'name': 'Spiero', 'message': ':_destinyOMEGALUL:', 'time': '1:59:03'} {'name': 'Spiero', 'message': ':_destinyOMEGALUL:', 'time': '1:59:03'} yes-(mocking reaction to the story)
# {'name': 'Shadow Moses', 'message': 'IM REALLY LIKE THAT', 'time': '1:59:05'} {'name': 'Shadow Moses', 'message': 'IM REALLY LIKE THAT', 'time': '1:59:05'} yes-(positive reaction to the story)
# {'name': 'Sanic The Hedge', 'message': 'that VOUSH fit', 'time': '1:59:07'} {'name': 'Sanic The Hedge', 'message': 'that VOUSH fit', 'time': '1:59:07'} yes-(amused reaction to the story)
# {'name': 'U WOT M8', 'message': 'Destiny Lamar', 'time': '1:59:08'} {'name': 'U WOT M8', 'message': 'Destiny Lamar', 'time': '1:59:08'} yes-(mocking reaction to the story)
# {'name': 'Joseph', 'message': 'Yes, bury the hatchet ', 'time': '1:59:11'} {'name': 'Joseph', 'message': 'Yes, bury the hatchet ', 'time': '1:59:11'} yes-(positive reaction to the story)
# {'name': 'Naruru', 'message': 'HUGE', 'time': '1:59:25'} {'name': 'Naruru', 'message': 'HUGE', 'time': '1:59:25'} yes-(positive reaction to the story)
# {'name': 'GRUM 🏳\u200d🌈', 'message': ':_destinyPepeLaugh::_destinyPepeLaugh:', 'time': '1:59:28'} {'name': 'GRUM 🏳\u200d🌈', 'message': ':_destinyPepeLaugh::_destinyPepeLaugh:', 'time': '1:59:28'} yes-(mocking reaction to the story)
# {'name': 'ytdiury', 'message': 'lmao', 'time': '1:59:30'} {'name': 'ytdiury', 'message': 'lmao', 'time': '1:59:30'} yes-(amused reaction to the story)
# {'name': 'socomchamp00', 'message': 'glazin', 'time': '1:59:30'} {'name': 'socomchamp00', 'message': 'glazin', 'time': '1:59:30'} yes-(positive reaction to the story)
# {'name': 'Joseph', 'message': 'Yuge celebrity ', 'time': '1:59:32'} {'name': 'Joseph', 'message': 'Yuge celebrity ', 'time': '1:59:32'} yes-(positive reaction to the story)
# {'name': 'Chip Riblet', 'message': 'the acolyte is so good', 'time': '1:59:35'} {'name': 'Chip Riblet', 'message': 'the acolyte is so good', 'time': '1:59:35'} yes-(positive reaction to the story)
# {'name': 'wrythe', 'message': '?????????', 'time': '1:59:41'} {'name': 'wrythe', 'message': '?????????', 'time': '1:59:41'} yes-(confused reaction to the story)
# {'name': 'Jack Hackenberg', 'message': 'YUGE ', 'time': '1:59:43'} {'name': 'Jack Hackenberg', 'message': 'YUGE ', 'time': '1:59:43'} yes-(positive reaction to the story)
# {'name': 'Xavier E', 'message': 'they were going easy on you last time', 'time': '1:59:46'} {'name': 'Xavier E', 'message': 'they were going easy on you last time', 'time': '1:59:46'} yes-(negative reaction to the story)
# {'name': 'RufflesRidges', 'message': 'little ironic', 'time': '1:59:47'} {'name': 'RufflesRidges', 'message': 'little ironic', 'time': '1:59:47'} yes-(ironic reaction to the story)
# {'name': 'LordLynkz', 'message': 'PROTECT YAH NECK', 'time': '1:59:47'} {'name': 'LordLynkz', 'message': 'PROTECT YAH NECK', 'time': '1:59:47'} yes-(threatening reaction to the story)
# {'name': 'wrythe', 'message': 'THEY ALWAYS SELF SNITCH', 'time': '1:59:48'} {'name': 'wrythe', 'message': 'THEY ALWAYS SELF SNITCH', 'time': '1:59:48'} yes-(positive reaction to the story)
# {'name': 'Naruru', 'message': 'ENORMOUS', 'time': '1:59:49'} {'name': 'Naruru', 'message': 'ENORMOUS', 'time': '1:59:49'} yes-(positive reaction to the story)
# {'name': 'Leon Kingsley', 'message': 'HAHA', 'time': '1:59:51'} {'name': 'Leon Kingsley', 'message': 'HAHA', 'time': '1:59:51'} yes-(amused reaction to the story)
# {'name': 'jayfeather2', 'message': 'we like to live in an echo chamber', 'time': '1:59:53'} {'name': 'jayfeather2', 'message': 'we like to live in an echo chamber', 'time': '1:59:53'} yes-(negative reaction to the story)
# {'name': 'bawk', 'message': 'i just wanna say retarded shit and not get push back from it ', 'time': '1:59:53'} {'name': 'bawk', 'message': 'i just wanna say retarded shit and not get push back from it ', 'time': '1:59:53'} yes-(negative reaction to the story)
# {'name': 'eli_ goose', 'message': 'chillstiny', 'time': '1:59:55'} {'name': 'eli_ goose', 'message': 'chillstiny', 'time': '1:59:55'} yes-(positive reaction to the story)
# {'name': 'Raiders Cat🕶🐢', 'message': ':_destinyFeelsWeird:', 'time': '1:59:56'} {'name': 'Raiders Cat🕶🐢', 'message': ':_destinyFeelsWeird:', 'time': '1:59:56'} yes-(confused reaction to the story)
# {'name': 'GRUM 🏳\u200d🌈', 'message': 'brawl:_destinyPainstiny:', 'time': '1:59:58'} {'name': 'GRUM 🏳\u200d🌈', 'message': 'brawl:_destinyPainstiny:', 'time': '1:59:58'} yes-(negative reaction to the story)
# {'name': 'Stway', 'message': 'true ', 'time': '1:59:59'} {'name': 'Stway', 'message': 'true ', 'time': '1:59:59'} yes-(positive reaction to the story)
# {'name': 'boosty', 'message': 'scared ', 'time': '1:59:59'} {'name': 'boosty', 'message': 'scared ', 'time': '1:59:59'} yes-(concerned reaction to the story)
# {'name': 'RandomTeacher61', 'message': 'This is fair', 'time': '2:00:00'} {'name': 'RandomTeacher61', 'message': 'This is fair', 'time': '2:00:00'} yes-(positive reaction to the story)
# {'name': 'Just4 Universe', 'message': 'Nuh UH:_destinyDggL:', 'time': '2:00:01'} {'name': 'Just4 Universe', 'message': 'Nuh UH:_destinyDggL:', 'time': '2:00:01'} yes-(positive reaction to the story)
# {'name': 'David Davidson', 'message': 'without worrying about beinr right', 'time': '2:00:02'} {'name': 'David Davidson', 'message': 'without worrying about beinr right', 'time': '2:00:02'} yes-(positive reaction to the story)
# {'name': 'Na~oodles', 'message': 'true', 'time': '2:00:02'} {'name': 'Na~oodles', 'message': 'true', 'time': '2:00:02'} yes-(positive reaction to the story)
# {'name': 'Take A Gander', 'message': 'True', 'time': '2:00:02'} {'name': 'Take A Gander', 'message': 'True', 'time': '2:00:02'} yes-(positive reaction to the story)
# {'name': 'Ozymandias', 'message': 'Not wrong :popcorn:', 'time': '2:00:02'} {'name': 'Ozymandias', 'message': 'Not wrong :popcorn:', 'time': '2:00:02'} yes-(positive reaction to the story)
# {'name': 'Sean Fleming', 'message': 'TRUE', 'time': '2:00:03'} {'name': 'Sean Fleming', 'message': 'TRUE', 'time': '2:00:03'} yes-(positive reaction to the story)
# {'name': 'Cooper', 'message': 'debate brained', 'time': '2:00:03'} {'name': 'Cooper', 'message': 'debate brained', 'time': '2:00:03'} yes-(negative reaction to the story)
# {'name': 'milkarn123', 'message': 'chills ', 'time': '2:00:03'} {'name': 'milkarn123', 'message': 'chills ', 'time': '2:00:03'} yes-(positive reaction to the story)
# {'name': 'Raiders Cat🕶🐢', 'message': ':_destinyPepe:', 'time': '2:00:04'} {'name': 'Raiders Cat🕶🐢', 'message': ':_destinyPepe:', 'time': '2:00:04'} yes-(positive reaction to the story)
# {'name': 'lIII', 'message': 'true', 'time': '2:00:04'} {'name': 'lIII', 'message': 'true', 'time': '2:00:04'} yes-(positive reaction to the story)
# {'name': 'Israel Garcia', 'message': ':.( lies', 'time': '2:00:05'} {'name': 'Israel Garcia', 'message': ':.( lies', 'time': '2:00:05'} yes-(negative reaction to the story)
# {'name': 'TallWhiteTee', 'message': 'good they are boring', 'time': '2:00:05'} {'name': 'TallWhiteTee', 'message': 'good they are boring', 'time': '2:00:05'} yes-(positive reaction to the story)
# {'name': 'Boredom', 'message': 'Based blood sport', 'time': '2:00:05'} {'name': 'Boredom', 'message': 'Based blood sport', 'time': '2:00:05'} yes-(positive reaction to the story)
# {'name': 'socomchamp00', 'message': 'dgg roll out', 'time': '2:00:08'} {'name': 'socomchamp00', 'message': 'dgg roll out', 'time': '2:00:08'} yes-(positive reaction to the story)
# {'name': 'Dr. Smell Zone', 'message': "When did this fight happen? I don't remember this bridge burning at all", 'time': '2:00:08'} {'name': 'Dr. Smell Zone', 'message': "When did this fight happen? I don't remember this bridge burning at all", 'time': '2:00:08'} yes-(confused reaction to the story)
# {'name': 'Santiago Navas', 'message': 'Destroy', 'time': '2:00:09'} {'name': 'Santiago Navas', 'message': 'Destroy', 'time': '2:00:09'} yes-(negative reaction to the story)
# {'name': 'N1ght_waLk', 'message': 'So they don’t want to talk to Destiny because they don’t want to lose?', 'time': '2:00:09'} {'name': 'N1ght_waLk', 'message': 'So they don’t want to talk to Destiny because they don’t want to lose?', 'time': '2:00:09'} yes-(positive reaction to the story)
# {'name': 'Salty Fish', 'message': 'echochamber', 'time': '2:00:10'} {'name': 'Salty Fish', 'message': 'echochamber', 'time': '2:00:10'} yes-(negative reaction to the story)
# {'name': 'Michael', 'message': 'Nah WE WANT BRIDGES', 'time': '2:00:11'} {'name': 'Michael', 'message': 'Nah WE WANT BRIDGES', 'time': '2:00:11'} yes-(positive reaction to the story)
# {'name': 'Fimbi', 'message': 'DESTROY', 'time': '2:00:15'} {'name': 'Fimbi', 'message': 'DESTROY', 'time': '2:00:15'} yes-(negative reaction to the story)
# {'name': 'Prince Stewart', 'message': '@destiny is that true?', 'time': '2:00:17'} {'name': 'Prince Stewart', 'message': '@destiny is that true?', 'time': '2:00:17'} yes-(off-topic question)
# {'name': 'Santiago Navas', 'message': ':_destinyGodstiny:', 'time': '2:00:17'} {'name': 'Santiago Navas', 'message': ':_destinyGodstiny:', 'time': '2:00:17'} yes-(positive reaction to the story)
# {'name': 'deadmodem', 'message': 'point out one lie', 'time': '2:00:20'} {'name': 'deadmodem', 'message': 'point out one lie', 'time': '2:00:20'} yes-(positive reaction to the story)
# {'name': 'Naruru', 'message': 'destiny does more studying than debating so...', 'time': '2:00:23'} {'name': 'Naruru', 'message': 'destiny does more studying than debating so...', 'time': '2:00:23'} yes-(positive reaction to the story)
# {'name': 'deadmodem', 'message': 'omegalol', 'time': '2:00:23'} {'name': 'deadmodem', 'message': 'omegalol', 'time': '2:00:23'} yes-(amused reaction to the story)
# {'name': 'ACE From Ottawa', 'message': 'Im a destroyer, yo', 'time': '2:00:26'} {'name': 'ACE From Ottawa', 'message': 'Im a destroyer, yo', 'time': '2:00:26'} yes-(positive reaction to the story)
# {'name': 'hooves', 'message': 'LOL', 'time': '2:00:28'} {'name': 'hooves', 'message': 'LOL', 'time': '2:00:28'} yes-(amused reaction to the story)
# {'name': 'lIII', 'message': 'LMAO', 'time': '2:00:28'} {'name': 'lIII', 'message': 'LMAO', 'time': '2:00:28'} yes-(amused reaction to the story)

# %%
serious_message
# Out:
# {6357: {'full': 'yes-(amused reaction to the story)',
#   'serious': True,
#   'chat_data': {'name': 'lIII', 'message': 'LMAO', 'time': '2:00:28'},
#   'transcript': "d would you trust a woman who keeps trying to seduce all of your friends? At every dinner party we throw, your.\n\nG: Friends get drunk and want to have sex with me. How is that my fucking problemus?\n\nC: You keep wearing these slutty little dressesk my little slthering girl.\n\nG: Okay, so I'll cover up, then.\n\nC: No, no, no, no.\n\nG: My body is my body, so.\n\nC: No, I'll cover.\n\nB: No, no, no.\n\nDestiny: I'll cover up.\n\nG: Cover her up, I think.\n\nDestiny: No, no, no. Don't touch me.\n\nD: I'm gonna hide from you then.\n\nDestiny: Know what?\n\nC: You feel that.\n\nDestiny: Show?\n\nC: I heat you.\n\nG: So does Timdy to eat or u. I got it, Tina. I got it.\n\nC: Ye.\n\nG: I'll be right back, girl. I'll be right back, chica.\n\nC: What do you drink and Tina?\n\nDestiny: I just.\n\nG: Just u sparkling water is great.\n\nC: Sparkling water. Yeah, that's a classic. Can hear it sizzle in your mouth. I have to go to the bathroom so bad. Sure. Yeah, yeah. Last door on the left.\n\nDestiny: Hi.\n\nG: French kiss my husband.\n\nDestiny: No, no, no, no, no, no, that's not.\n\nG: That'totally fine if you did. I just wanted to know because it's'more in my house, I guess.\n\nC: Yeah, no, nothing like that. He's just telling me how grateful you guys were to have a babysitter. Yeah, I came.\n\nG: I once. I once kissed a woman named Ingrid.\n\nDestiny: O. I was in college.\n\nG: She was on the water boo team. She was really strong.\n\nDestiny: She did everything strong.\n\nC: So I think I'm gonna head out.\n\nDestiny: Because it feels like you guys are gonna stay in.\n\nG: You want to head out cause my husband's sexuallyau to you?\n\nDestiny: No, no, I didn tn.\n\nG: So Tina wants to leave cause you made her feel uncomfortable? Why would that be?\n\nDestiny: I didn't say that.\n\nG: I didn't say she's leaving cause she feels like you sexually assaulted her.\n\nDestiny: No, I didn't say that.\n\nC: I got a question. Why is our sun chinese?\n\nG: I've told you this, Ken. My uncle is chinese.\n\nC: That guy right there. I know you've explained it to me, but it doesn't make any sense.\n\nDestiny: Ken, I have told you a hundred times, my uncle is Chinese.\n\nG: That is fucking why.\n\nC: No, no, no, no, no.\n\nD: Stop, stop.\n\nC: Heyi I'm Tina. It's so nice to look in there. What's happening there?\n\nG: Your par are just having a chat and you meet.\n\nC: Hang out here for a second. If you wanted to listen to me.\n\nG: When I fucking talk to you, huh?\n\nC: You want to play video games? I'd love to play video games. Yeah. Let's get into your room. A.\n\nDestiny: Keep dancing. Don't stop, please.\n\nG: Keep dancing.\n\nDestiny: Far away but still so near'go.\n\nC: On. Mommy's coming.\n\nG: Mommy's coming.\n\nDestiny: Mommy's coming right now I just to I'm in the corner watching your kiss her o.\n\nC: Jimmy and not your real dad.\n\nG: I know.\n\nC: I need papa knock knock o.\n\nDestiny: For tonight? Yeah, of course.\n\nC: Next week.\n\nDestiny: Next weekend? Yeah. I'm not available next week. I'm sorry.\n\nB: Okay.\n\nC: Let'S grossina your back. Can he come again next week?\n\nG: Affirmative.\n\nDestiny: Over and out. If I can ret return.\n\nC: Oh, hi. Was admiring the ship.\n\nDestiny: You guys are so freaking awesome. And you rock my socks off. Thank you so much for supporting. And if you want to find other ways to support, easy one.\n\nC: We got a sweet merch. And they didn't give me a size that fits, which kind of pisses me off. But you guys can order whatever size you want and it'll fit you. And also maybe drink some Friday beers this summer. It's available in all these cities. It's not available in your city. Let us know. We'll be there.\n\nDestiny: We're one call away.\n\nC: As a matter of fact, my number is you. Cut it.\n\nDestiny: Fuck it. All right. One more peaked in high school. We watch the Douglas Meti debate. I don't know, maybe. We'll see.\n\nB: Hey, you can't be in here, man.\n\nC: Sorry.\n\nDestiny:  ...

# %%
item_c=0
for key, value in serious_message.items():
    # print(key, value)
    item_c+=1
print(item_c)
# Out:
# 1

# %%
value
# Out:
# {'full': "yes - Serious message about Kendrick Lamar's Juneteenth show",
#  'serious': True,
#  'chat_data': {'name': 'Esteban',
#   'message': 'Kendrick Juneteenth show soon :cold_face:',
#   'time': '2:25'},
#  'transcript': "Destiny: Oh, wow. What a, what a wow. What a wowzer day. What happened? We did a show this morning with Ayla and Earon. Tonight we're doing one with Hutch and Dan and maybe, maybe Arnold join that one. We'll see who'en Aya's business partner person. How big are the. I don't know what said you want to be streaming tomorrow on the 20th? Oh, yeah. Fuck. I got travel shit coming up. Tomorrow I go to talk to Alex O'Connor. I don't think I'll be streaming at all, probably. And then I think on the 25th I go to LA for a thing and I think that's all I have right now. Did the gray zone guy respond? I haven't even reached out to him yet. U too much shit. Now we're just in front of the camera. What's up? I think that the video files that are recorded on those cameras are too large for working non locally. I don't know what to do. Do you think I should transcode the files before I upload them to the Google Drive for August or what's like an acceptable. What do you think is like the minimum acceptable quality for mixing video files together? Ask augentation. No. What he wants. True. I see somebody just like tell me what to do. Tired of making every decision for everything. This program uses Fmmeg to cut files without transcoding. By doing keyframe cut, you can cut files at certain points where it seems fine and send the videos that way. I don't understand what you mean by that. What aims to be the ultimate cross platform thing? Main features lossless trimming and cutting a video on audio files, which we saving space by rough cutting your large video files. If it's lossless, what percentage is the compression? Like how much space do you gain? If it's lossless that means there's no compression. No, that's not what lossless means. You can still compress stuff. What camera am I shooting on? The blackmaic pocket camera. Six k. Like the smallest options for you can do prores and you can choose the rightost option, but its still filling. I think I get 7 hours of footage on a 512 GBTE card. Meaning it'probably about an hour. What would that be like an hour'like? 80 gbte basically about. So if I record a two hour thing, it's about 160 gigs plus or times three because I have two other cameras. So 160, what is that? 300 plus 180 is 480gb. So about half a terabyte. And that's on like the lowest setting. I think I have to find a way to compress these files. I don't think it's realistic because if I. It is for me. What is August, he has a gig Internet. I feel like if you've got a gigabit line it's not that big of a deal. How long should it take to upload? 500gb times eight is in bits. So it's 4000 gigabits on a one gigabit line. So divided by 60 seconds or divided by 60 is minutes. So it take about a minute to upload. Is that right? Am I doing that right? About 1 minute to upload half a terabyte. I feel like I did something wrong here. Okay, 500gb times eight, that's 4000 gigabits. If I do a gigabit per second divided by 60 is, is that 1 hour or was that 1 minute? Why am I mind fucking myself here? No, it's an hour. It would never be a minute. Yeah. 66 minutes. 4000 gigabits divided by 60. Oh, because it's per second. So this is in minutes. Yeah. Okay, so it would d be about an hour. So it would be about a little over an hour to upload. So probably like at max 2 hours to upload, 2 hours to download and then 2 hours to upload, 2 hours to download, and then august shoots the video. That shouldn't be that bad, right? What's the issue August is having? The issue is I'm shooting him, I'm recording from all three cameras and I'm just sen, I'm sending him the recordings from the cameras now so that he can do all the switching and everything optimally instead of trying to do it live. But the issue is it's just they're very very very big files. They're very big files. Gate connection is not both up and down. Generally it will be. Usually it's fiber. Fiber lines are usually symmetrical. Not always, but what's your words per minute? I'll donate 100  ...

# %%
same_segment_serious_messages=[]
temp_segment=[]
previous_transcript=None
for serious_message in serious_messages:
    for key, value in serious_message.items():
        if (value["transcript"]!=previous_transcript) and (previous_transcript!=None):
            same_segment_serious_messages.append(temp_segment)
            temp_segment=[]
        else:
            temp_segment.append(value)

        previous_transcript=value["transcript"]

if temp_segment!=[]:
    same_segment_serious_messages.append(temp_segment)

# %%
for segment_serious_messages in same_segment_serious_messages:
    print(len(segment_serious_messages))
# Out:
# 197
# 115
# 227
# 183
# 242
# 110
# 229
# 208
# 289

# %%
same_segment_serious_messages[-1]
# Out:
# [{'full': 'yes-(a message about an upcoming event)',
#   'serious': True,
#   'chat_data': {'name': 'Nightbot',
#    'message': 'See upcoming events: https://destiny.gg/schedule',
#    'time': '1:48:48'},
#   'transcript': "d would you trust a woman who keeps trying to seduce all of your friends? At every dinner party we throw, your.\n\nG: Friends get drunk and want to have sex with me. How is that my fucking problemus?\n\nC: You keep wearing these slutty little dressesk my little slthering girl.\n\nG: Okay, so I'll cover up, then.\n\nC: No, no, no, no.\n\nG: My body is my body, so.\n\nC: No, I'll cover.\n\nB: No, no, no.\n\nDestiny: I'll cover up.\n\nG: Cover her up, I think.\n\nDestiny: No, no, no. Don't touch me.\n\nD: I'm gonna hide from you then.\n\nDestiny: Know what?\n\nC: You feel that.\n\nDestiny: Show?\n\nC: I heat you.\n\nG: So does Timdy to eat or u. I got it, Tina. I got it.\n\nC: Ye.\n\nG: I'll be right back, girl. I'll be right back, chica.\n\nC: What do you drink and Tina?\n\nDestiny: I just.\n\nG: Just u sparkling water is great.\n\nC: Sparkling water. Yeah, that's a classic. Can hear it sizzle in your mouth. I have to go to the bathroom so bad. Sure. Yeah, yeah. Last door on the left.\n\nDestiny: Hi.\n\nG: French kiss my husband.\n\nDestiny: No, no, no, no, no, no, that's not.\n\nG: That'totally fine if you did. I just wanted to know because it's'more in my house, I guess.\n\nC: Yeah, no, nothing like that. He's just telling me how grateful you guys were to have a babysitter. Yeah, I came.\n\nG: I once. I once kissed a woman named Ingrid.\n\nDestiny: O. I was in college.\n\nG: She was on the water boo team. She was really strong.\n\nDestiny: She did everything strong.\n\nC: So I think I'm gonna head out.\n\nDestiny: Because it feels like you guys are gonna stay in.\n\nG: You want to head out cause my husband's sexuallyau to you?\n\nDestiny: No, no, I didn tn.\n\nG: So Tina wants to leave cause you made her feel uncomfortable? Why would that be?\n\nDestiny: I didn't say that.\n\nG: I didn't say she's leaving cause she feels like you sexually assaulted her.\n\nDestiny: No, I didn't say that.\n\nC: I got a question. Why is our sun chinese?\n\nG: I've told you this, Ken. My uncle is chinese.\n\nC: That guy right there. I know you've explained it to me, but it doesn't make any sense.\n\nDestiny: Ken, I have told you a hundred times, my uncle is Chinese.\n\nG: That is fucking why.\n\nC: No, no, no, no, no.\n\nD: Stop, stop.\n\nC: Heyi I'm Tina. It's so nice to look in there. What's happening there?\n\nG: Your par are just having a chat and you meet.\n\nC: Hang out here for a second. If you wanted to listen to me.\n\nG: When I fucking talk to you, huh?\n\nC: You want to play video games? I'd love to play video games. Yeah. Let's get into your room. A.\n\nDestiny: Keep dancing. Don't stop, please.\n\nG: Keep dancing.\n\nDestiny: Far away but still so near'go.\n\nC: On. Mommy's coming.\n\nG: Mommy's coming.\n\nDestiny: Mommy's coming right now I just to I'm in the corner watching your kiss her o.\n\nC: Jimmy and not your real dad.\n\nG: I know.\n\nC: I need papa knock knock o.\n\nDestiny: For tonight? Yeah, of course.\n\nC: Next week.\n\nDestiny: Next weekend? Yeah. I'm not available next week. I'm sorry.\n\nB: Okay.\n\nC: Let'S grossina your back. Can he come again next week?\n\nG: Affirmative.\n\nDestiny: Over and out. If I can ret return.\n\nC: Oh, hi. Was admiring the ship.\n\nDestiny: You guys are so freaking awesome. And you rock my socks off. Thank you so much for supporting. And if you want to find other ways to support, easy one.\n\nC: We got a sweet merch. And they didn't give me a size that fits, which kind of pisses me off. But you guys can order whatever size you want and it'll fit you. And also maybe drink some Friday beers this summer. It's available in all these cities. It's not available in your city. Let us know. We'll be there.\n\nDestiny: We're one call away.\n\nC: As a matter of fact, my number is you. Cut it.\n\nDestiny: Fuck it. All right. One more peaked in high school. We watch the Douglas Meti debate. I don't know, maybe. We'll see.\n\nB: Hey, you can't be in here, man.\n\nC: Sorry.\n\nDestiny:  ...
#  {'full': 'yes-(a serious message about the content)',
#   'serious': True,
#   'chat_data': {'name': 'Joseph',
#    'message': "That's a good question",
#    'time': '1:48:53'},
#   'transcript': "d would you trust a woman who keeps trying to seduce all of your friends? At every dinner party we throw, your.\n\nG: Friends get drunk and want to have sex with me. How is that my fucking problemus?\n\nC: You keep wearing these slutty little dressesk my little slthering girl.\n\nG: Okay, so I'll cover up, then.\n\nC: No, no, no, no.\n\nG: My body is my body, so.\n\nC: No, I'll cover.\n\nB: No, no, no.\n\nDestiny: I'll cover up.\n\nG: Cover her up, I think.\n\nDestiny: No, no, no. Don't touch me.\n\nD: I'm gonna hide from you then.\n\nDestiny: Know what?\n\nC: You feel that.\n\nDestiny: Show?\n\nC: I heat you.\n\nG: So does Timdy to eat or u. I got it, Tina. I got it.\n\nC: Ye.\n\nG: I'll be right back, girl. I'll be right back, chica.\n\nC: What do you drink and Tina?\n\nDestiny: I just.\n\nG: Just u sparkling water is great.\n\nC: Sparkling water. Yeah, that's a classic. Can hear it sizzle in your mouth. I have to go to the bathroom so bad. Sure. Yeah, yeah. Last door on the left.\n\nDestiny: Hi.\n\nG: French kiss my husband.\n\nDestiny: No, no, no, no, no, no, that's not.\n\nG: That'totally fine if you did. I just wanted to know because it's'more in my house, I guess.\n\nC: Yeah, no, nothing like that. He's just telling me how grateful you guys were to have a babysitter. Yeah, I came.\n\nG: I once. I once kissed a woman named Ingrid.\n\nDestiny: O. I was in college.\n\nG: She was on the water boo team. She was really strong.\n\nDestiny: She did everything strong.\n\nC: So I think I'm gonna head out.\n\nDestiny: Because it feels like you guys are gonna stay in.\n\nG: You want to head out cause my husband's sexuallyau to you?\n\nDestiny: No, no, I didn tn.\n\nG: So Tina wants to leave cause you made her feel uncomfortable? Why would that be?\n\nDestiny: I didn't say that.\n\nG: I didn't say she's leaving cause she feels like you sexually assaulted her.\n\nDestiny: No, I didn't say that.\n\nC: I got a question. Why is our sun chinese?\n\nG: I've told you this, Ken. My uncle is chinese.\n\nC: That guy right there. I know you've explained it to me, but it doesn't make any sense.\n\nDestiny: Ken, I have told you a hundred times, my uncle is Chinese.\n\nG: That is fucking why.\n\nC: No, no, no, no, no.\n\nD: Stop, stop.\n\nC: Heyi I'm Tina. It's so nice to look in there. What's happening there?\n\nG: Your par are just having a chat and you meet.\n\nC: Hang out here for a second. If you wanted to listen to me.\n\nG: When I fucking talk to you, huh?\n\nC: You want to play video games? I'd love to play video games. Yeah. Let's get into your room. A.\n\nDestiny: Keep dancing. Don't stop, please.\n\nG: Keep dancing.\n\nDestiny: Far away but still so near'go.\n\nC: On. Mommy's coming.\n\nG: Mommy's coming.\n\nDestiny: Mommy's coming right now I just to I'm in the corner watching your kiss her o.\n\nC: Jimmy and not your real dad.\n\nG: I know.\n\nC: I need papa knock knock o.\n\nDestiny: For tonight? Yeah, of course.\n\nC: Next week.\n\nDestiny: Next weekend? Yeah. I'm not available next week. I'm sorry.\n\nB: Okay.\n\nC: Let'S grossina your back. Can he come again next week?\n\nG: Affirmative.\n\nDestiny: Over and out. If I can ret return.\n\nC: Oh, hi. Was admiring the ship.\n\nDestiny: You guys are so freaking awesome. And you rock my socks off. Thank you so much for supporting. And if you want to find other ways to support, easy one.\n\nC: We got a sweet merch. And they didn't give me a size that fits, which kind of pisses me off. But you guys can order whatever size you want and it'll fit you. And also maybe drink some Friday beers this summer. It's available in all these cities. It's not available in your city. Let us know. We'll be there.\n\nDestiny: We're one call away.\n\nC: As a matter of fact, my number is you. Cut it.\n\nDestiny: Fuck it. All right. One more peaked in high school. We watch the Douglas Meti debate. I don't know, maybe. We'll see.\n\nB: Hey, you can't be in here, man.\n\nC: Sorry.\n\nDestiny:  ...
#  {'full': 'yes-(a serious message about the content)',
#   'serious': True,
#   'chat_data': {'name': 'Gabriel Ramirez',
#    'message': 'so she did the uncle?',
#    'time': '1:49:08'},
#   'transcript': "d would you trust a woman who keeps trying to seduce all of your friends? At every dinner party we throw, your.\n\nG: Friends get drunk and want to have sex with me. How is that my fucking problemus?\n\nC: You keep wearing these slutty little dressesk my little slthering girl.\n\nG: Okay, so I'll cover up, then.\n\nC: No, no, no, no.\n\nG: My body is my body, so.\n\nC: No, I'll cover.\n\nB: No, no, no.\n\nDestiny: I'll cover up.\n\nG: Cover her up, I think.\n\nDestiny: No, no, no. Don't touch me.\n\nD: I'm gonna hide from you then.\n\nDestiny: Know what?\n\nC: You feel that.\n\nDestiny: Show?\n\nC: I heat you.\n\nG: So does Timdy to eat or u. I got it, Tina. I got it.\n\nC: Ye.\n\nG: I'll be right back, girl. I'll be right back, chica.\n\nC: What do you drink and Tina?\n\nDestiny: I just.\n\nG: Just u sparkling water is great.\n\nC: Sparkling water. Yeah, that's a classic. Can hear it sizzle in your mouth. I have to go to the bathroom so bad. Sure. Yeah, yeah. Last door on the left.\n\nDestiny: Hi.\n\nG: French kiss my husband.\n\nDestiny: No, no, no, no, no, no, that's not.\n\nG: That'totally fine if you did. I just wanted to know because it's'more in my house, I guess.\n\nC: Yeah, no, nothing like that. He's just telling me how grateful you guys were to have a babysitter. Yeah, I came.\n\nG: I once. I once kissed a woman named Ingrid.\n\nDestiny: O. I was in college.\n\nG: She was on the water boo team. She was really strong.\n\nDestiny: She did everything strong.\n\nC: So I think I'm gonna head out.\n\nDestiny: Because it feels like you guys are gonna stay in.\n\nG: You want to head out cause my husband's sexuallyau to you?\n\nDestiny: No, no, I didn tn.\n\nG: So Tina wants to leave cause you made her feel uncomfortable? Why would that be?\n\nDestiny: I didn't say that.\n\nG: I didn't say she's leaving cause she feels like you sexually assaulted her.\n\nDestiny: No, I didn't say that.\n\nC: I got a question. Why is our sun chinese?\n\nG: I've told you this, Ken. My uncle is chinese.\n\nC: That guy right there. I know you've explained it to me, but it doesn't make any sense.\n\nDestiny: Ken, I have told you a hundred times, my uncle is Chinese.\n\nG: That is fucking why.\n\nC: No, no, no, no, no.\n\nD: Stop, stop.\n\nC: Heyi I'm Tina. It's so nice to look in there. What's happening there?\n\nG: Your par are just having a chat and you meet.\n\nC: Hang out here for a second. If you wanted to listen to me.\n\nG: When I fucking talk to you, huh?\n\nC: You want to play video games? I'd love to play video games. Yeah. Let's get into your room. A.\n\nDestiny: Keep dancing. Don't stop, please.\n\nG: Keep dancing.\n\nDestiny: Far away but still so near'go.\n\nC: On. Mommy's coming.\n\nG: Mommy's coming.\n\nDestiny: Mommy's coming right now I just to I'm in the corner watching your kiss her o.\n\nC: Jimmy and not your real dad.\n\nG: I know.\n\nC: I need papa knock knock o.\n\nDestiny: For tonight? Yeah, of course.\n\nC: Next week.\n\nDestiny: Next weekend? Yeah. I'm not available next week. I'm sorry.\n\nB: Okay.\n\nC: Let'S grossina your back. Can he come again next week?\n\nG: Affirmative.\n\nDestiny: Over and out. If I can ret return.\n\nC: Oh, hi. Was admiring the ship.\n\nDestiny: You guys are so freaking awesome. And you rock my socks off. Thank you so much for supporting. And if you want to find other ways to support, easy one.\n\nC: We got a sweet merch. And they didn't give me a size that fits, which kind of pisses me off. But you guys can order whatever size you want and it'll fit you. And also maybe drink some Friday beers this summer. It's available in all these cities. It's not available in your city. Let us know. We'll be there.\n\nDestiny: We're one call away.\n\nC: As a matter of fact, my number is you. Cut it.\n\nDestiny: Fuck it. All right. One more peaked in high school. We watch the Douglas Meti debate. I don't know, maybe. We'll see.\n\nB: Hey, you can't be in here, man.\n\nC: Sorry.\n\nDestiny:  ...
#  {'full': 'yes-(a serious message about the content)',
#   'serious': True,
#   'chat_data': {'name': 'grahamcracker',
#    'message': 'she had sex with her uncle?',
#    'time': '1:49:09'},
#   'transcript': "d would you trust a woman who keeps trying to seduce all of your friends? At every dinner party we throw, your.\n\nG: Friends get drunk and want to have sex with me. How is that my fucking problemus?\n\nC: You keep wearing these slutty little dressesk my little slthering girl.\n\nG: Okay, so I'll cover up, then.\n\nC: No, no, no, no.\n\nG: My body is my body, so.\n\nC: No, I'll cover.\n\nB: No, no, no.\n\nDestiny: I'll cover up.\n\nG: Cover her up, I think.\n\nDestiny: No, no, no. Don't touch me.\n\nD: I'm gonna hide from you then.\n\nDestiny: Know what?\n\nC: You feel that.\n\nDestiny: Show?\n\nC: I heat you.\n\nG: So does Timdy to eat or u. I got it, Tina. I got it.\n\nC: Ye.\n\nG: I'll be right back, girl. I'll be right back, chica.\n\nC: What do you drink and Tina?\n\nDestiny: I just.\n\nG: Just u sparkling water is great.\n\nC: Sparkling water. Yeah, that's a classic. Can hear it sizzle in your mouth. I have to go to the bathroom so bad. Sure. Yeah, yeah. Last door on the left.\n\nDestiny: Hi.\n\nG: French kiss my husband.\n\nDestiny: No, no, no, no, no, no, that's not.\n\nG: That'totally fine if you did. I just wanted to know because it's'more in my house, I guess.\n\nC: Yeah, no, nothing like that. He's just telling me how grateful you guys were to have a babysitter. Yeah, I came.\n\nG: I once. I once kissed a woman named Ingrid.\n\nDestiny: O. I was in college.\n\nG: She was on the water boo team. She was really strong.\n\nDestiny: She did everything strong.\n\nC: So I think I'm gonna head out.\n\nDestiny: Because it feels like you guys are gonna stay in.\n\nG: You want to head out cause my husband's sexuallyau to you?\n\nDestiny: No, no, I didn tn.\n\nG: So Tina wants to leave cause you made her feel uncomfortable? Why would that be?\n\nDestiny: I didn't say that.\n\nG: I didn't say she's leaving cause she feels like you sexually assaulted her.\n\nDestiny: No, I didn't say that.\n\nC: I got a question. Why is our sun chinese?\n\nG: I've told you this, Ken. My uncle is chinese.\n\nC: That guy right there. I know you've explained it to me, but it doesn't make any sense.\n\nDestiny: Ken, I have told you a hundred times, my uncle is Chinese.\n\nG: That is fucking why.\n\nC: No, no, no, no, no.\n\nD: Stop, stop.\n\nC: Heyi I'm Tina. It's so nice to look in there. What's happening there?\n\nG: Your par are just having a chat and you meet.\n\nC: Hang out here for a second. If you wanted to listen to me.\n\nG: When I fucking talk to you, huh?\n\nC: You want to play video games? I'd love to play video games. Yeah. Let's get into your room. A.\n\nDestiny: Keep dancing. Don't stop, please.\n\nG: Keep dancing.\n\nDestiny: Far away but still so near'go.\n\nC: On. Mommy's coming.\n\nG: Mommy's coming.\n\nDestiny: Mommy's coming right now I just to I'm in the corner watching your kiss her o.\n\nC: Jimmy and not your real dad.\n\nG: I know.\n\nC: I need papa knock knock o.\n\nDestiny: For tonight? Yeah, of course.\n\nC: Next week.\n\nDestiny: Next weekend? Yeah. I'm not available next week. I'm sorry.\n\nB: Okay.\n\nC: Let'S grossina your back. Can he come again next week?\n\nG: Affirmative.\n\nDestiny: Over and out. If I can ret return.\n\nC: Oh, hi. Was admiring the ship.\n\nDestiny: You guys are so freaking awesome. And you rock my socks off. Thank you so much for supporting. And if you want to find other ways to support, easy one.\n\nC: We got a sweet merch. And they didn't give me a size that fits, which kind of pisses me off. But you guys can order whatever size you want and it'll fit you. And also maybe drink some Friday beers this summer. It's available in all these cities. It's not available in your city. Let us know. We'll be there.\n\nDestiny: We're one call away.\n\nC: As a matter of fact, my number is you. Cut it.\n\nDestiny: Fuck it. All right. One more peaked in high school. We watch the Douglas Meti debate. I don't know, maybe. We'll see.\n\nB: Hey, you can't be in here, man.\n\nC: Sorry.\n\nDestiny:  ...
#  {'full': 'yes-(a serious message about the content)',
#   'serious': True,
#   'chat_data': {'name': 'Jason Christensen',
#    'message': '....So she fucked her uncle?',
#    'time': '1:49:09'},
#   'transcript': "d would you trust a woman who keeps trying to seduce all of your friends? At every dinner party we throw, your.\n\nG: Friends get drunk and want to have sex with me. How is that my fucking problemus?\n\nC: You keep wearing these slutty little dressesk my little slthering girl.\n\nG: Okay, so I'll cover up, then.\n\nC: No, no, no, no.\n\nG: My body is my body, so.\n\nC: No, I'll cover.\n\nB: No, no, no.\n\nDestiny: I'll cover up.\n\nG: Cover her up, I think.\n\nDestiny: No, no, no. Don't touch me.\n\nD: I'm gonna hide from you then.\n\nDestiny: Know what?\n\nC: You feel that.\n\nDestiny: Show?\n\nC: I heat you.\n\nG: So does Timdy to eat or u. I got it, Tina. I got it.\n\nC: Ye.\n\nG: I'll be right back, girl. I'll be right back, chica.\n\nC: What do you drink and Tina?\n\nDestiny: I just.\n\nG: Just u sparkling water is great.\n\nC: Sparkling water. Yeah, that's a classic. Can hear it sizzle in your mouth. I have to go to the bathroom so bad. Sure. Yeah, yeah. Last door on the left.\n\nDestiny: Hi.\n\nG: French kiss my husband.\n\nDestiny: No, no, no, no, no, no, that's not.\n\nG: That'totally fine if you did. I just wanted to know because it's'more in my house, I guess.\n\nC: Yeah, no, nothing like that. He's just telling me how grateful you guys were to have a babysitter. Yeah, I came.\n\nG: I once. I once kissed a woman named Ingrid.\n\nDestiny: O. I was in college.\n\nG: She was on the water boo team. She was really strong.\n\nDestiny: She did everything strong.\n\nC: So I think I'm gonna head out.\n\nDestiny: Because it feels like you guys are gonna stay in.\n\nG: You want to head out cause my husband's sexuallyau to you?\n\nDestiny: No, no, I didn tn.\n\nG: So Tina wants to leave cause you made her feel uncomfortable? Why would that be?\n\nDestiny: I didn't say that.\n\nG: I didn't say she's leaving cause she feels like you sexually assaulted her.\n\nDestiny: No, I didn't say that.\n\nC: I got a question. Why is our sun chinese?\n\nG: I've told you this, Ken. My uncle is chinese.\n\nC: That guy right there. I know you've explained it to me, but it doesn't make any sense.\n\nDestiny: Ken, I have told you a hundred times, my uncle is Chinese.\n\nG: That is fucking why.\n\nC: No, no, no, no, no.\n\nD: Stop, stop.\n\nC: Heyi I'm Tina. It's so nice to look in there. What's happening there?\n\nG: Your par are just having a chat and you meet.\n\nC: Hang out here for a second. If you wanted to listen to me.\n\nG: When I fucking talk to you, huh?\n\nC: You want to play video games? I'd love to play video games. Yeah. Let's get into your room. A.\n\nDestiny: Keep dancing. Don't stop, please.\n\nG: Keep dancing.\n\nDestiny: Far away but still so near'go.\n\nC: On. Mommy's coming.\n\nG: Mommy's coming.\n\nDestiny: Mommy's coming right now I just to I'm in the corner watching your kiss her o.\n\nC: Jimmy and not your real dad.\n\nG: I know.\n\nC: I need papa knock knock o.\n\nDestiny: For tonight? Yeah, of course.\n\nC: Next week.\n\nDestiny: Next weekend? Yeah. I'm not available next week. I'm sorry.\n\nB: Okay.\n\nC: Let'S grossina your back. Can he come again next week?\n\nG: Affirmative.\n\nDestiny: Over and out. If I can ret return.\n\nC: Oh, hi. Was admiring the ship.\n\nDestiny: You guys are so freaking awesome. And you rock my socks off. Thank you so much for supporting. And if you want to find other ways to support, easy one.\n\nC: We got a sweet merch. And they didn't give me a size that fits, which kind of pisses me off. But you guys can order whatever size you want and it'll fit you. And also maybe drink some Friday beers this summer. It's available in all these cities. It's not available in your city. Let us know. We'll be there.\n\nDestiny: We're one call away.\n\nC: As a matter of fact, my number is you. Cut it.\n\nDestiny: Fuck it. All right. One more peaked in high school. We watch the Douglas Meti debate. I don't know, maybe. We'll see.\n\nB: Hey, you can't be in here, man.\n\nC: Sorry.\n\nDestiny:  ...
#  {'full': 'yes-(a serious message about the content)',
#   'serious': True,
#   'chat_data': {'name': 'Just4 Universe',
#    'message': 'so she banged her uncle .... :_destinyPepe:',
#    'time': '1:49:10'},
#   'transcript': "d would you trust a woman who keeps trying to seduce all of your friends? At every dinner party we throw, your.\n\nG: Friends get drunk and want to have sex with me. How is that my fucking problemus?\n\nC: You keep wearing these slutty little dressesk my little slthering girl.\n\nG: Okay, so I'll cover up, then.\n\nC: No, no, no, no.\n\nG: My body is my body, so.\n\nC: No, I'll cover.\n\nB: No, no, no.\n\nDestiny: I'll cover up.\n\nG: Cover her up, I think.\n\nDestiny: No, no, no. Don't touch me.\n\nD: I'm gonna hide from you then.\n\nDestiny: Know what?\n\nC: You feel that.\n\nDestiny: Show?\n\nC: I heat you.\n\nG: So does Timdy to eat or u. I got it, Tina. I got it.\n\nC: Ye.\n\nG: I'll be right back, girl. I'll be right back, chica.\n\nC: What do you drink and Tina?\n\nDestiny: I just.\n\nG: Just u sparkling water is great.\n\nC: Sparkling water. Yeah, that's a classic. Can hear it sizzle in your mouth. I have to go to the bathroom so bad. Sure. Yeah, yeah. Last door on the left.\n\nDestiny: Hi.\n\nG: French kiss my husband.\n\nDestiny: No, no, no, no, no, no, that's not.\n\nG: That'totally fine if you did. I just wanted to know because it's'more in my house, I guess.\n\nC: Yeah, no, nothing like that. He's just telling me how grateful you guys were to have a babysitter. Yeah, I came.\n\nG: I once. I once kissed a woman named Ingrid.\n\nDestiny: O. I was in college.\n\nG: She was on the water boo team. She was really strong.\n\nDestiny: She did everything strong.\n\nC: So I think I'm gonna head out.\n\nDestiny: Because it feels like you guys are gonna stay in.\n\nG: You want to head out cause my husband's sexuallyau to you?\n\nDestiny: No, no, I didn tn.\n\nG: So Tina wants to leave cause you made her feel uncomfortable? Why would that be?\n\nDestiny: I didn't say that.\n\nG: I didn't say she's leaving cause she feels like you sexually assaulted her.\n\nDestiny: No, I didn't say that.\n\nC: I got a question. Why is our sun chinese?\n\nG: I've told you this, Ken. My uncle is chinese.\n\nC: That guy right there. I know you've explained it to me, but it doesn't make any sense.\n\nDestiny: Ken, I have told you a hundred times, my uncle is Chinese.\n\nG: That is fucking why.\n\nC: No, no, no, no, no.\n\nD: Stop, stop.\n\nC: Heyi I'm Tina. It's so nice to look in there. What's happening there?\n\nG: Your par are just having a chat and you meet.\n\nC: Hang out here for a second. If you wanted to listen to me.\n\nG: When I fucking talk to you, huh?\n\nC: You want to play video games? I'd love to play video games. Yeah. Let's get into your room. A.\n\nDestiny: Keep dancing. Don't stop, please.\n\nG: Keep dancing.\n\nDestiny: Far away but still so near'go.\n\nC: On. Mommy's coming.\n\nG: Mommy's coming.\n\nDestiny: Mommy's coming right now I just to I'm in the corner watching your kiss her o.\n\nC: Jimmy and not your real dad.\n\nG: I know.\n\nC: I need papa knock knock o.\n\nDestiny: For tonight? Yeah, of course.\n\nC: Next week.\n\nDestiny: Next weekend? Yeah. I'm not available next week. I'm sorry.\n\nB: Okay.\n\nC: Let'S grossina your back. Can he come again next week?\n\nG: Affirmative.\n\nDestiny: Over and out. If I can ret return.\n\nC: Oh, hi. Was admiring the ship.\n\nDestiny: You guys are so freaking awesome. And you rock my socks off. Thank you so much for supporting. And if you want to find other ways to support, easy one.\n\nC: We got a sweet merch. And they didn't give me a size that fits, which kind of pisses me off. But you guys can order whatever size you want and it'll fit you. And also maybe drink some Friday beers this summer. It's available in all these cities. It's not available in your city. Let us know. We'll be there.\n\nDestiny: We're one call away.\n\nC: As a matter of fact, my number is you. Cut it.\n\nDestiny: Fuck it. All right. One more peaked in high school. We watch the Douglas Meti debate. I don't know, maybe. We'll see.\n\nB: Hey, you can't be in here, man.\n\nC: Sorry.\n\nDestiny:  ...
#  {'full': 'yes-(expressing discomfort)',
#   'serious': True,
#   'chat_data': {'name': 'Omnicast',
#    'message': 'Bro this is so uncomfortable ',
#    'time': '1:49:46'},
#   'transcript': "d would you trust a woman who keeps trying to seduce all of your friends? At every dinner party we throw, your.\n\nG: Friends get drunk and want to have sex with me. How is that my fucking problemus?\n\nC: You keep wearing these slutty little dressesk my little slthering girl.\n\nG: Okay, so I'll cover up, then.\n\nC: No, no, no, no.\n\nG: My body is my body, so.\n\nC: No, I'll cover.\n\nB: No, no, no.\n\nDestiny: I'll cover up.\n\nG: Cover her up, I think.\n\nDestiny: No, no, no. Don't touch me.\n\nD: I'm gonna hide from you then.\n\nDestiny: Know what?\n\nC: You feel that.\n\nDestiny: Show?\n\nC: I heat you.\n\nG: So does Timdy to eat or u. I got it, Tina. I got it.\n\nC: Ye.\n\nG: I'll be right back, girl. I'll be right back, chica.\n\nC: What do you drink and Tina?\n\nDestiny: I just.\n\nG: Just u sparkling water is great.\n\nC: Sparkling water. Yeah, that's a classic. Can hear it sizzle in your mouth. I have to go to the bathroom so bad. Sure. Yeah, yeah. Last door on the left.\n\nDestiny: Hi.\n\nG: French kiss my husband.\n\nDestiny: No, no, no, no, no, no, that's not.\n\nG: That'totally fine if you did. I just wanted to know because it's'more in my house, I guess.\n\nC: Yeah, no, nothing like that. He's just telling me how grateful you guys were to have a babysitter. Yeah, I came.\n\nG: I once. I once kissed a woman named Ingrid.\n\nDestiny: O. I was in college.\n\nG: She was on the water boo team. She was really strong.\n\nDestiny: She did everything strong.\n\nC: So I think I'm gonna head out.\n\nDestiny: Because it feels like you guys are gonna stay in.\n\nG: You want to head out cause my husband's sexuallyau to you?\n\nDestiny: No, no, I didn tn.\n\nG: So Tina wants to leave cause you made her feel uncomfortable? Why would that be?\n\nDestiny: I didn't say that.\n\nG: I didn't say she's leaving cause she feels like you sexually assaulted her.\n\nDestiny: No, I didn't say that.\n\nC: I got a question. Why is our sun chinese?\n\nG: I've told you this, Ken. My uncle is chinese.\n\nC: That guy right there. I know you've explained it to me, but it doesn't make any sense.\n\nDestiny: Ken, I have told you a hundred times, my uncle is Chinese.\n\nG: That is fucking why.\n\nC: No, no, no, no, no.\n\nD: Stop, stop.\n\nC: Heyi I'm Tina. It's so nice to look in there. What's happening there?\n\nG: Your par are just having a chat and you meet.\n\nC: Hang out here for a second. If you wanted to listen to me.\n\nG: When I fucking talk to you, huh?\n\nC: You want to play video games? I'd love to play video games. Yeah. Let's get into your room. A.\n\nDestiny: Keep dancing. Don't stop, please.\n\nG: Keep dancing.\n\nDestiny: Far away but still so near'go.\n\nC: On. Mommy's coming.\n\nG: Mommy's coming.\n\nDestiny: Mommy's coming right now I just to I'm in the corner watching your kiss her o.\n\nC: Jimmy and not your real dad.\n\nG: I know.\n\nC: I need papa knock knock o.\n\nDestiny: For tonight? Yeah, of course.\n\nC: Next week.\n\nDestiny: Next weekend? Yeah. I'm not available next week. I'm sorry.\n\nB: Okay.\n\nC: Let'S grossina your back. Can he come again next week?\n\nG: Affirmative.\n\nDestiny: Over and out. If I can ret return.\n\nC: Oh, hi. Was admiring the ship.\n\nDestiny: You guys are so freaking awesome. And you rock my socks off. Thank you so much for supporting. And if you want to find other ways to support, easy one.\n\nC: We got a sweet merch. And they didn't give me a size that fits, which kind of pisses me off. But you guys can order whatever size you want and it'll fit you. And also maybe drink some Friday beers this summer. It's available in all these cities. It's not available in your city. Let us know. We'll be there.\n\nDestiny: We're one call away.\n\nC: As a matter of fact, my number is you. Cut it.\n\nDestiny: Fuck it. All right. One more peaked in high school. We watch the Douglas Meti debate. I don't know, maybe. We'll see.\n\nB: Hey, you can't be in here, man.\n\nC: Sorry.\n\nDestiny:  ...
#  {'full': 'yes-(expressing concern)',
#   'serious': True,
#   'chat_data': {'name': 'Sz',
#    'message': 'call the fucking police bra :loudly_crying_face::loudly_crying_face::loudly_crying_face:',
#    'time': '1:50:21'},
#   'transcript': "d would you trust a woman who keeps trying to seduce all of your friends? At every dinner party we throw, your.\n\nG: Friends get drunk and want to have sex with me. How is that my fucking problemus?\n\nC: You keep wearing these slutty little dressesk my little slthering girl.\n\nG: Okay, so I'll cover up, then.\n\nC: No, no, no, no.\n\nG: My body is my body, so.\n\nC: No, I'll cover.\n\nB: No, no, no.\n\nDestiny: I'll cover up.\n\nG: Cover her up, I think.\n\nDestiny: No, no, no. Don't touch me.\n\nD: I'm gonna hide from you then.\n\nDestiny: Know what?\n\nC: You feel that.\n\nDestiny: Show?\n\nC: I heat you.\n\nG: So does Timdy to eat or u. I got it, Tina. I got it.\n\nC: Ye.\n\nG: I'll be right back, girl. I'll be right back, chica.\n\nC: What do you drink and Tina?\n\nDestiny: I just.\n\nG: Just u sparkling water is great.\n\nC: Sparkling water. Yeah, that's a classic. Can hear it sizzle in your mouth. I have to go to the bathroom so bad. Sure. Yeah, yeah. Last door on the left.\n\nDestiny: Hi.\n\nG: French kiss my husband.\n\nDestiny: No, no, no, no, no, no, that's not.\n\nG: That'totally fine if you did. I just wanted to know because it's'more in my house, I guess.\n\nC: Yeah, no, nothing like that. He's just telling me how grateful you guys were to have a babysitter. Yeah, I came.\n\nG: I once. I once kissed a woman named Ingrid.\n\nDestiny: O. I was in college.\n\nG: She was on the water boo team. She was really strong.\n\nDestiny: She did everything strong.\n\nC: So I think I'm gonna head out.\n\nDestiny: Because it feels like you guys are gonna stay in.\n\nG: You want to head out cause my husband's sexuallyau to you?\n\nDestiny: No, no, I didn tn.\n\nG: So Tina wants to leave cause you made her feel uncomfortable? Why would that be?\n\nDestiny: I didn't say that.\n\nG: I didn't say she's leaving cause she feels like you sexually assaulted her.\n\nDestiny: No, I didn't say that.\n\nC: I got a question. Why is our sun chinese?\n\nG: I've told you this, Ken. My uncle is chinese.\n\nC: That guy right there. I know you've explained it to me, but it doesn't make any sense.\n\nDestiny: Ken, I have told you a hundred times, my uncle is Chinese.\n\nG: That is fucking why.\n\nC: No, no, no, no, no.\n\nD: Stop, stop.\n\nC: Heyi I'm Tina. It's so nice to look in there. What's happening there?\n\nG: Your par are just having a chat and you meet.\n\nC: Hang out here for a second. If you wanted to listen to me.\n\nG: When I fucking talk to you, huh?\n\nC: You want to play video games? I'd love to play video games. Yeah. Let's get into your room. A.\n\nDestiny: Keep dancing. Don't stop, please.\n\nG: Keep dancing.\n\nDestiny: Far away but still so near'go.\n\nC: On. Mommy's coming.\n\nG: Mommy's coming.\n\nDestiny: Mommy's coming right now I just to I'm in the corner watching your kiss her o.\n\nC: Jimmy and not your real dad.\n\nG: I know.\n\nC: I need papa knock knock o.\n\nDestiny: For tonight? Yeah, of course.\n\nC: Next week.\n\nDestiny: Next weekend? Yeah. I'm not available next week. I'm sorry.\n\nB: Okay.\n\nC: Let'S grossina your back. Can he come again next week?\n\nG: Affirmative.\n\nDestiny: Over and out. If I can ret return.\n\nC: Oh, hi. Was admiring the ship.\n\nDestiny: You guys are so freaking awesome. And you rock my socks off. Thank you so much for supporting. And if you want to find other ways to support, easy one.\n\nC: We got a sweet merch. And they didn't give me a size that fits, which kind of pisses me off. But you guys can order whatever size you want and it'll fit you. And also maybe drink some Friday beers this summer. It's available in all these cities. It's not available in your city. Let us know. We'll be there.\n\nDestiny: We're one call away.\n\nC: As a matter of fact, my number is you. Cut it.\n\nDestiny: Fuck it. All right. One more peaked in high school. We watch the Douglas Meti debate. I don't know, maybe. We'll see.\n\nB: Hey, you can't be in here, man.\n\nC: Sorry.\n\nDestiny:  ...
#  {'full': 'yes-(expressing shock)',
#   'serious': True,
#   'chat_data': {'name': 'Boredom',
#    'message': 'This is the most insane shit I’ve ever watched',
#    'time': '1:50:24'},
#   'transcript': "d would you trust a woman who keeps trying to seduce all of your friends? At every dinner party we throw, your.\n\nG: Friends get drunk and want to have sex with me. How is that my fucking problemus?\n\nC: You keep wearing these slutty little dressesk my little slthering girl.\n\nG: Okay, so I'll cover up, then.\n\nC: No, no, no, no.\n\nG: My body is my body, so.\n\nC: No, I'll cover.\n\nB: No, no, no.\n\nDestiny: I'll cover up.\n\nG: Cover her up, I think.\n\nDestiny: No, no, no. Don't touch me.\n\nD: I'm gonna hide from you then.\n\nDestiny: Know what?\n\nC: You feel that.\n\nDestiny: Show?\n\nC: I heat you.\n\nG: So does Timdy to eat or u. I got it, Tina. I got it.\n\nC: Ye.\n\nG: I'll be right back, girl. I'll be right back, chica.\n\nC: What do you drink and Tina?\n\nDestiny: I just.\n\nG: Just u sparkling water is great.\n\nC: Sparkling water. Yeah, that's a classic. Can hear it sizzle in your mouth. I have to go to the bathroom so bad. Sure. Yeah, yeah. Last door on the left.\n\nDestiny: Hi.\n\nG: French kiss my husband.\n\nDestiny: No, no, no, no, no, no, that's not.\n\nG: That'totally fine if you did. I just wanted to know because it's'more in my house, I guess.\n\nC: Yeah, no, nothing like that. He's just telling me how grateful you guys were to have a babysitter. Yeah, I came.\n\nG: I once. I once kissed a woman named Ingrid.\n\nDestiny: O. I was in college.\n\nG: She was on the water boo team. She was really strong.\n\nDestiny: She did everything strong.\n\nC: So I think I'm gonna head out.\n\nDestiny: Because it feels like you guys are gonna stay in.\n\nG: You want to head out cause my husband's sexuallyau to you?\n\nDestiny: No, no, I didn tn.\n\nG: So Tina wants to leave cause you made her feel uncomfortable? Why would that be?\n\nDestiny: I didn't say that.\n\nG: I didn't say she's leaving cause she feels like you sexually assaulted her.\n\nDestiny: No, I didn't say that.\n\nC: I got a question. Why is our sun chinese?\n\nG: I've told you this, Ken. My uncle is chinese.\n\nC: That guy right there. I know you've explained it to me, but it doesn't make any sense.\n\nDestiny: Ken, I have told you a hundred times, my uncle is Chinese.\n\nG: That is fucking why.\n\nC: No, no, no, no, no.\n\nD: Stop, stop.\n\nC: Heyi I'm Tina. It's so nice to look in there. What's happening there?\n\nG: Your par are just having a chat and you meet.\n\nC: Hang out here for a second. If you wanted to listen to me.\n\nG: When I fucking talk to you, huh?\n\nC: You want to play video games? I'd love to play video games. Yeah. Let's get into your room. A.\n\nDestiny: Keep dancing. Don't stop, please.\n\nG: Keep dancing.\n\nDestiny: Far away but still so near'go.\n\nC: On. Mommy's coming.\n\nG: Mommy's coming.\n\nDestiny: Mommy's coming right now I just to I'm in the corner watching your kiss her o.\n\nC: Jimmy and not your real dad.\n\nG: I know.\n\nC: I need papa knock knock o.\n\nDestiny: For tonight? Yeah, of course.\n\nC: Next week.\n\nDestiny: Next weekend? Yeah. I'm not available next week. I'm sorry.\n\nB: Okay.\n\nC: Let'S grossina your back. Can he come again next week?\n\nG: Affirmative.\n\nDestiny: Over and out. If I can ret return.\n\nC: Oh, hi. Was admiring the ship.\n\nDestiny: You guys are so freaking awesome. And you rock my socks off. Thank you so much for supporting. And if you want to find other ways to support, easy one.\n\nC: We got a sweet merch. And they didn't give me a size that fits, which kind of pisses me off. But you guys can order whatever size you want and it'll fit you. And also maybe drink some Friday beers this summer. It's available in all these cities. It's not available in your city. Let us know. We'll be there.\n\nDestiny: We're one call away.\n\nC: As a matter of fact, my number is you. Cut it.\n\nDestiny: Fuck it. All right. One more peaked in high school. We watch the Douglas Meti debate. I don't know, maybe. We'll see.\n\nB: Hey, you can't be in here, man.\n\nC: Sorry.\n\nDestiny:  ...
#  {'full': 'yes-(this is an enthusiastic reaction to the content)',
#   'serious': True,
#   'chat_data': {'name': 'Naruru',
#    'message': 'this is so fucking amazing',
#    'time': '1:50:56'},
#   'transcript': "d would you trust a woman who keeps trying to seduce all of your friends? At every dinner party we throw, your.\n\nG: Friends get drunk and want to have sex with me. How is that my fucking problemus?\n\nC: You keep wearing these slutty little dressesk my little slthering girl.\n\nG: Okay, so I'll cover up, then.\n\nC: No, no, no, no.\n\nG: My body is my body, so.\n\nC: No, I'll cover.\n\nB: No, no, no.\n\nDestiny: I'll cover up.\n\nG: Cover her up, I think.\n\nDestiny: No, no, no. Don't touch me.\n\nD: I'm gonna hide from you then.\n\nDestiny: Know what?\n\nC: You feel that.\n\nDestiny: Show?\n\nC: I heat you.\n\nG: So does Timdy to eat or u. I got it, Tina. I got it.\n\nC: Ye.\n\nG: I'll be right back, girl. I'll be right back, chica.\n\nC: What do you drink and Tina?\n\nDestiny: I just.\n\nG: Just u sparkling water is great.\n\nC: Sparkling water. Yeah, that's a classic. Can hear it sizzle in your mouth. I have to go to the bathroom so bad. Sure. Yeah, yeah. Last door on the left.\n\nDestiny: Hi.\n\nG: French kiss my husband.\n\nDestiny: No, no, no, no, no, no, that's not.\n\nG: That'totally fine if you did. I just wanted to know because it's'more in my house, I guess.\n\nC: Yeah, no, nothing like that. He's just telling me how grateful you guys were to have a babysitter. Yeah, I came.\n\nG: I once. I once kissed a woman named Ingrid.\n\nDestiny: O. I was in college.\n\nG: She was on the water boo team. She was really strong.\n\nDestiny: She did everything strong.\n\nC: So I think I'm gonna head out.\n\nDestiny: Because it feels like you guys are gonna stay in.\n\nG: You want to head out cause my husband's sexuallyau to you?\n\nDestiny: No, no, I didn tn.\n\nG: So Tina wants to leave cause you made her feel uncomfortable? Why would that be?\n\nDestiny: I didn't say that.\n\nG: I didn't say she's leaving cause she feels like you sexually assaulted her.\n\nDestiny: No, I didn't say that.\n\nC: I got a question. Why is our sun chinese?\n\nG: I've told you this, Ken. My uncle is chinese.\n\nC: That guy right there. I know you've explained it to me, but it doesn't make any sense.\n\nDestiny: Ken, I have told you a hundred times, my uncle is Chinese.\n\nG: That is fucking why.\n\nC: No, no, no, no, no.\n\nD: Stop, stop.\n\nC: Heyi I'm Tina. It's so nice to look in there. What's happening there?\n\nG: Your par are just having a chat and you meet.\n\nC: Hang out here for a second. If you wanted to listen to me.\n\nG: When I fucking talk to you, huh?\n\nC: You want to play video games? I'd love to play video games. Yeah. Let's get into your room. A.\n\nDestiny: Keep dancing. Don't stop, please.\n\nG: Keep dancing.\n\nDestiny: Far away but still so near'go.\n\nC: On. Mommy's coming.\n\nG: Mommy's coming.\n\nDestiny: Mommy's coming right now I just to I'm in the corner watching your kiss her o.\n\nC: Jimmy and not your real dad.\n\nG: I know.\n\nC: I need papa knock knock o.\n\nDestiny: For tonight? Yeah, of course.\n\nC: Next week.\n\nDestiny: Next weekend? Yeah. I'm not available next week. I'm sorry.\n\nB: Okay.\n\nC: Let'S grossina your back. Can he come again next week?\n\nG: Affirmative.\n\nDestiny: Over and out. If I can ret return.\n\nC: Oh, hi. Was admiring the ship.\n\nDestiny: You guys are so freaking awesome. And you rock my socks off. Thank you so much for supporting. And if you want to find other ways to support, easy one.\n\nC: We got a sweet merch. And they didn't give me a size that fits, which kind of pisses me off. But you guys can order whatever size you want and it'll fit you. And also maybe drink some Friday beers this summer. It's available in all these cities. It's not available in your city. Let us know. We'll be there.\n\nDestiny: We're one call away.\n\nC: As a matter of fact, my number is you. Cut it.\n\nDestiny: Fuck it. All right. One more peaked in high school. We watch the Douglas Meti debate. I don't know, maybe. We'll see.\n\nB: Hey, you can't be in here, man.\n\nC: Sorry.\n\nDestiny:  ...
#  {'full': 'yes-(this is a reasonable reaction to the content)',
#   'serious': True,
#   'chat_data': {'name': 'Mujoujinsoku',
#    'message': "Yeah... I'll rejoin stream once whatever this is is over. lol",
#    'time': '1:50:58'},
#   'transcript': "d would you trust a woman who keeps trying to seduce all of your friends? At every dinner party we throw, your.\n\nG: Friends get drunk and want to have sex with me. How is that my fucking problemus?\n\nC: You keep wearing these slutty little dressesk my little slthering girl.\n\nG: Okay, so I'll cover up, then.\n\nC: No, no, no, no.\n\nG: My body is my body, so.\n\nC: No, I'll cover.\n\nB: No, no, no.\n\nDestiny: I'll cover up.\n\nG: Cover her up, I think.\n\nDestiny: No, no, no. Don't touch me.\n\nD: I'm gonna hide from you then.\n\nDestiny: Know what?\n\nC: You feel that.\n\nDestiny: Show?\n\nC: I heat you.\n\nG: So does Timdy to eat or u. I got it, Tina. I got it.\n\nC: Ye.\n\nG: I'll be right back, girl. I'll be right back, chica.\n\nC: What do you drink and Tina?\n\nDestiny: I just.\n\nG: Just u sparkling water is great.\n\nC: Sparkling water. Yeah, that's a classic. Can hear it sizzle in your mouth. I have to go to the bathroom so bad. Sure. Yeah, yeah. Last door on the left.\n\nDestiny: Hi.\n\nG: French kiss my husband.\n\nDestiny: No, no, no, no, no, no, that's not.\n\nG: That'totally fine if you did. I just wanted to know because it's'more in my house, I guess.\n\nC: Yeah, no, nothing like that. He's just telling me how grateful you guys were to have a babysitter. Yeah, I came.\n\nG: I once. I once kissed a woman named Ingrid.\n\nDestiny: O. I was in college.\n\nG: She was on the water boo team. She was really strong.\n\nDestiny: She did everything strong.\n\nC: So I think I'm gonna head out.\n\nDestiny: Because it feels like you guys are gonna stay in.\n\nG: You want to head out cause my husband's sexuallyau to you?\n\nDestiny: No, no, I didn tn.\n\nG: So Tina wants to leave cause you made her feel uncomfortable? Why would that be?\n\nDestiny: I didn't say that.\n\nG: I didn't say she's leaving cause she feels like you sexually assaulted her.\n\nDestiny: No, I didn't say that.\n\nC: I got a question. Why is our sun chinese?\n\nG: I've told you this, Ken. My uncle is chinese.\n\nC: That guy right there. I know you've explained it to me, but it doesn't make any sense.\n\nDestiny: Ken, I have told you a hundred times, my uncle is Chinese.\n\nG: That is fucking why.\n\nC: No, no, no, no, no.\n\nD: Stop, stop.\n\nC: Heyi I'm Tina. It's so nice to look in there. What's happening there?\n\nG: Your par are just having a chat and you meet.\n\nC: Hang out here for a second. If you wanted to listen to me.\n\nG: When I fucking talk to you, huh?\n\nC: You want to play video games? I'd love to play video games. Yeah. Let's get into your room. A.\n\nDestiny: Keep dancing. Don't stop, please.\n\nG: Keep dancing.\n\nDestiny: Far away but still so near'go.\n\nC: On. Mommy's coming.\n\nG: Mommy's coming.\n\nDestiny: Mommy's coming right now I just to I'm in the corner watching your kiss her o.\n\nC: Jimmy and not your real dad.\n\nG: I know.\n\nC: I need papa knock knock o.\n\nDestiny: For tonight? Yeah, of course.\n\nC: Next week.\n\nDestiny: Next weekend? Yeah. I'm not available next week. I'm sorry.\n\nB: Okay.\n\nC: Let'S grossina your back. Can he come again next week?\n\nG: Affirmative.\n\nDestiny: Over and out. If I can ret return.\n\nC: Oh, hi. Was admiring the ship.\n\nDestiny: You guys are so freaking awesome. And you rock my socks off. Thank you so much for supporting. And if you want to find other ways to support, easy one.\n\nC: We got a sweet merch. And they didn't give me a size that fits, which kind of pisses me off. But you guys can order whatever size you want and it'll fit you. And also maybe drink some Friday beers this summer. It's available in all these cities. It's not available in your city. Let us know. We'll be there.\n\nDestiny: We're one call away.\n\nC: As a matter of fact, my number is you. Cut it.\n\nDestiny: Fuck it. All right. One more peaked in high school. We watch the Douglas Meti debate. I don't know, maybe. We'll see.\n\nB: Hey, you can't be in here, man.\n\nC: Sorry.\n\nDestiny:  ...
#  {'full': 'yes-(this is a reasonable reaction to the content)',
#   'serious': True,
#   'chat_data': {'name': 'lOcIEe',
#    'message': 'Thats a whole trip',
#    'time': '1:50:58'},
# ...
#  {'full': 'yes-(positive reaction to the story)',
#   'serious': True,
#   'chat_data': {'name': 'ACE From Ottawa',
#    'message': 'Im a destroyer, yo',
#    'time': '2:00:26'},
#   'transcript': "d would you trust a woman who keeps trying to seduce all of your friends? At every dinner party we throw, your.\n\nG: Friends get drunk and want to have sex with me. How is that my fucking problemus?\n\nC: You keep wearing these slutty little dressesk my little slthering girl.\n\nG: Okay, so I'll cover up, then.\n\nC: No, no, no, no.\n\nG: My body is my body, so.\n\nC: No, I'll cover.\n\nB: No, no, no.\n\nDestiny: I'll cover up.\n\nG: Cover her up, I think.\n\nDestiny: No, no, no. Don't touch me.\n\nD: I'm gonna hide from you then.\n\nDestiny: Know what?\n\nC: You feel that.\n\nDestiny: Show?\n\nC: I heat you.\n\nG: So does Timdy to eat or u. I got it, Tina. I got it.\n\nC: Ye.\n\nG: I'll be right back, girl. I'll be right back, chica.\n\nC: What do you drink and Tina?\n\nDestiny: I just.\n\nG: Just u sparkling water is great.\n\nC: Sparkling water. Yeah, that's a classic. Can hear it sizzle in your mouth. I have to go to the bathroom so bad. Sure. Yeah, yeah. Last door on the left.\n\nDestiny: Hi.\n\nG: French kiss my husband.\n\nDestiny: No, no, no, no, no, no, that's not.\n\nG: That'totally fine if you did. I just wanted to know because it's'more in my house, I guess.\n\nC: Yeah, no, nothing like that. He's just telling me how grateful you guys were to have a babysitter. Yeah, I came.\n\nG: I once. I once kissed a woman named Ingrid.\n\nDestiny: O. I was in college.\n\nG: She was on the water boo team. She was really strong.\n\nDestiny: She did everything strong.\n\nC: So I think I'm gonna head out.\n\nDestiny: Because it feels like you guys are gonna stay in.\n\nG: You want to head out cause my husband's sexuallyau to you?\n\nDestiny: No, no, I didn tn.\n\nG: So Tina wants to leave cause you made her feel uncomfortable? Why would that be?\n\nDestiny: I didn't say that.\n\nG: I didn't say she's leaving cause she feels like you sexually assaulted her.\n\nDestiny: No, I didn't say that.\n\nC: I got a question. Why is our sun chinese?\n\nG: I've told you this, Ken. My uncle is chinese.\n\nC: That guy right there. I know you've explained it to me, but it doesn't make any sense.\n\nDestiny: Ken, I have told you a hundred times, my uncle is Chinese.\n\nG: That is fucking why.\n\nC: No, no, no, no, no.\n\nD: Stop, stop.\n\nC: Heyi I'm Tina. It's so nice to look in there. What's happening there?\n\nG: Your par are just having a chat and you meet.\n\nC: Hang out here for a second. If you wanted to listen to me.\n\nG: When I fucking talk to you, huh?\n\nC: You want to play video games? I'd love to play video games. Yeah. Let's get into your room. A.\n\nDestiny: Keep dancing. Don't stop, please.\n\nG: Keep dancing.\n\nDestiny: Far away but still so near'go.\n\nC: On. Mommy's coming.\n\nG: Mommy's coming.\n\nDestiny: Mommy's coming right now I just to I'm in the corner watching your kiss her o.\n\nC: Jimmy and not your real dad.\n\nG: I know.\n\nC: I need papa knock knock o.\n\nDestiny: For tonight? Yeah, of course.\n\nC: Next week.\n\nDestiny: Next weekend? Yeah. I'm not available next week. I'm sorry.\n\nB: Okay.\n\nC: Let'S grossina your back. Can he come again next week?\n\nG: Affirmative.\n\nDestiny: Over and out. If I can ret return.\n\nC: Oh, hi. Was admiring the ship.\n\nDestiny: You guys are so freaking awesome. And you rock my socks off. Thank you so much for supporting. And if you want to find other ways to support, easy one.\n\nC: We got a sweet merch. And they didn't give me a size that fits, which kind of pisses me off. But you guys can order whatever size you want and it'll fit you. And also maybe drink some Friday beers this summer. It's available in all these cities. It's not available in your city. Let us know. We'll be there.\n\nDestiny: We're one call away.\n\nC: As a matter of fact, my number is you. Cut it.\n\nDestiny: Fuck it. All right. One more peaked in high school. We watch the Douglas Meti debate. I don't know, maybe. We'll see.\n\nB: Hey, you can't be in here, man.\n\nC: Sorry.\n\nDestiny:  ...
#  {'full': 'yes-(amused reaction to the story)',
#   'serious': True,
#   'chat_data': {'name': 'hooves', 'message': 'LOL', 'time': '2:00:28'},
#   'transcript': "d would you trust a woman who keeps trying to seduce all of your friends? At every dinner party we throw, your.\n\nG: Friends get drunk and want to have sex with me. How is that my fucking problemus?\n\nC: You keep wearing these slutty little dressesk my little slthering girl.\n\nG: Okay, so I'll cover up, then.\n\nC: No, no, no, no.\n\nG: My body is my body, so.\n\nC: No, I'll cover.\n\nB: No, no, no.\n\nDestiny: I'll cover up.\n\nG: Cover her up, I think.\n\nDestiny: No, no, no. Don't touch me.\n\nD: I'm gonna hide from you then.\n\nDestiny: Know what?\n\nC: You feel that.\n\nDestiny: Show?\n\nC: I heat you.\n\nG: So does Timdy to eat or u. I got it, Tina. I got it.\n\nC: Ye.\n\nG: I'll be right back, girl. I'll be right back, chica.\n\nC: What do you drink and Tina?\n\nDestiny: I just.\n\nG: Just u sparkling water is great.\n\nC: Sparkling water. Yeah, that's a classic. Can hear it sizzle in your mouth. I have to go to the bathroom so bad. Sure. Yeah, yeah. Last door on the left.\n\nDestiny: Hi.\n\nG: French kiss my husband.\n\nDestiny: No, no, no, no, no, no, that's not.\n\nG: That'totally fine if you did. I just wanted to know because it's'more in my house, I guess.\n\nC: Yeah, no, nothing like that. He's just telling me how grateful you guys were to have a babysitter. Yeah, I came.\n\nG: I once. I once kissed a woman named Ingrid.\n\nDestiny: O. I was in college.\n\nG: She was on the water boo team. She was really strong.\n\nDestiny: She did everything strong.\n\nC: So I think I'm gonna head out.\n\nDestiny: Because it feels like you guys are gonna stay in.\n\nG: You want to head out cause my husband's sexuallyau to you?\n\nDestiny: No, no, I didn tn.\n\nG: So Tina wants to leave cause you made her feel uncomfortable? Why would that be?\n\nDestiny: I didn't say that.\n\nG: I didn't say she's leaving cause she feels like you sexually assaulted her.\n\nDestiny: No, I didn't say that.\n\nC: I got a question. Why is our sun chinese?\n\nG: I've told you this, Ken. My uncle is chinese.\n\nC: That guy right there. I know you've explained it to me, but it doesn't make any sense.\n\nDestiny: Ken, I have told you a hundred times, my uncle is Chinese.\n\nG: That is fucking why.\n\nC: No, no, no, no, no.\n\nD: Stop, stop.\n\nC: Heyi I'm Tina. It's so nice to look in there. What's happening there?\n\nG: Your par are just having a chat and you meet.\n\nC: Hang out here for a second. If you wanted to listen to me.\n\nG: When I fucking talk to you, huh?\n\nC: You want to play video games? I'd love to play video games. Yeah. Let's get into your room. A.\n\nDestiny: Keep dancing. Don't stop, please.\n\nG: Keep dancing.\n\nDestiny: Far away but still so near'go.\n\nC: On. Mommy's coming.\n\nG: Mommy's coming.\n\nDestiny: Mommy's coming right now I just to I'm in the corner watching your kiss her o.\n\nC: Jimmy and not your real dad.\n\nG: I know.\n\nC: I need papa knock knock o.\n\nDestiny: For tonight? Yeah, of course.\n\nC: Next week.\n\nDestiny: Next weekend? Yeah. I'm not available next week. I'm sorry.\n\nB: Okay.\n\nC: Let'S grossina your back. Can he come again next week?\n\nG: Affirmative.\n\nDestiny: Over and out. If I can ret return.\n\nC: Oh, hi. Was admiring the ship.\n\nDestiny: You guys are so freaking awesome. And you rock my socks off. Thank you so much for supporting. And if you want to find other ways to support, easy one.\n\nC: We got a sweet merch. And they didn't give me a size that fits, which kind of pisses me off. But you guys can order whatever size you want and it'll fit you. And also maybe drink some Friday beers this summer. It's available in all these cities. It's not available in your city. Let us know. We'll be there.\n\nDestiny: We're one call away.\n\nC: As a matter of fact, my number is you. Cut it.\n\nDestiny: Fuck it. All right. One more peaked in high school. We watch the Douglas Meti debate. I don't know, maybe. We'll see.\n\nB: Hey, you can't be in here, man.\n\nC: Sorry.\n\nDestiny:  ...
#  {'full': 'yes-(amused reaction to the story)',
#   'serious': True,
#   'chat_data': {'name': 'lIII', 'message': 'LMAO', 'time': '2:00:28'},
#   'transcript': "d would you trust a woman who keeps trying to seduce all of your friends? At every dinner party we throw, your.\n\nG: Friends get drunk and want to have sex with me. How is that my fucking problemus?\n\nC: You keep wearing these slutty little dressesk my little slthering girl.\n\nG: Okay, so I'll cover up, then.\n\nC: No, no, no, no.\n\nG: My body is my body, so.\n\nC: No, I'll cover.\n\nB: No, no, no.\n\nDestiny: I'll cover up.\n\nG: Cover her up, I think.\n\nDestiny: No, no, no. Don't touch me.\n\nD: I'm gonna hide from you then.\n\nDestiny: Know what?\n\nC: You feel that.\n\nDestiny: Show?\n\nC: I heat you.\n\nG: So does Timdy to eat or u. I got it, Tina. I got it.\n\nC: Ye.\n\nG: I'll be right back, girl. I'll be right back, chica.\n\nC: What do you drink and Tina?\n\nDestiny: I just.\n\nG: Just u sparkling water is great.\n\nC: Sparkling water. Yeah, that's a classic. Can hear it sizzle in your mouth. I have to go to the bathroom so bad. Sure. Yeah, yeah. Last door on the left.\n\nDestiny: Hi.\n\nG: French kiss my husband.\n\nDestiny: No, no, no, no, no, no, that's not.\n\nG: That'totally fine if you did. I just wanted to know because it's'more in my house, I guess.\n\nC: Yeah, no, nothing like that. He's just telling me how grateful you guys were to have a babysitter. Yeah, I came.\n\nG: I once. I once kissed a woman named Ingrid.\n\nDestiny: O. I was in college.\n\nG: She was on the water boo team. She was really strong.\n\nDestiny: She did everything strong.\n\nC: So I think I'm gonna head out.\n\nDestiny: Because it feels like you guys are gonna stay in.\n\nG: You want to head out cause my husband's sexuallyau to you?\n\nDestiny: No, no, I didn tn.\n\nG: So Tina wants to leave cause you made her feel uncomfortable? Why would that be?\n\nDestiny: I didn't say that.\n\nG: I didn't say she's leaving cause she feels like you sexually assaulted her.\n\nDestiny: No, I didn't say that.\n\nC: I got a question. Why is our sun chinese?\n\nG: I've told you this, Ken. My uncle is chinese.\n\nC: That guy right there. I know you've explained it to me, but it doesn't make any sense.\n\nDestiny: Ken, I have told you a hundred times, my uncle is Chinese.\n\nG: That is fucking why.\n\nC: No, no, no, no, no.\n\nD: Stop, stop.\n\nC: Heyi I'm Tina. It's so nice to look in there. What's happening there?\n\nG: Your par are just having a chat and you meet.\n\nC: Hang out here for a second. If you wanted to listen to me.\n\nG: When I fucking talk to you, huh?\n\nC: You want to play video games? I'd love to play video games. Yeah. Let's get into your room. A.\n\nDestiny: Keep dancing. Don't stop, please.\n\nG: Keep dancing.\n\nDestiny: Far away but still so near'go.\n\nC: On. Mommy's coming.\n\nG: Mommy's coming.\n\nDestiny: Mommy's coming right now I just to I'm in the corner watching your kiss her o.\n\nC: Jimmy and not your real dad.\n\nG: I know.\n\nC: I need papa knock knock o.\n\nDestiny: For tonight? Yeah, of course.\n\nC: Next week.\n\nDestiny: Next weekend? Yeah. I'm not available next week. I'm sorry.\n\nB: Okay.\n\nC: Let'S grossina your back. Can he come again next week?\n\nG: Affirmative.\n\nDestiny: Over and out. If I can ret return.\n\nC: Oh, hi. Was admiring the ship.\n\nDestiny: You guys are so freaking awesome. And you rock my socks off. Thank you so much for supporting. And if you want to find other ways to support, easy one.\n\nC: We got a sweet merch. And they didn't give me a size that fits, which kind of pisses me off. But you guys can order whatever size you want and it'll fit you. And also maybe drink some Friday beers this summer. It's available in all these cities. It's not available in your city. Let us know. We'll be there.\n\nDestiny: We're one call away.\n\nC: As a matter of fact, my number is you. Cut it.\n\nDestiny: Fuck it. All right. One more peaked in high school. We watch the Douglas Meti debate. I don't know, maybe. We'll see.\n\nB: Hey, you can't be in here, man.\n\nC: Sorry.\n\nDestiny:  ...

# %% [markdown]
# # REDO RECAPS

# %%
from pytube import YouTube
import discord
import html2text
import traceback
all_transcript_data=await saf.get_all_data()
keys=views.keys

# %%
async def redo_recap(transcript_model_datas, vector_embeedding_bool=True, summary_segments_bool=True, meta_summary_bool=True, video_metadata_bool=True):

    discord_recaps_to_send=[]
    for transcript_model_data in transcript_model_datas:
        yt_id=transcript_model_data.video_id
        print("REDOING RECAP FOR: ", yt_id)
        raw_transcript_data=transcript_model_data.raw_transcript_data
        save_raw_transcript_data={"raw_transcript_data": raw_transcript_data}

        # Process to make regular and linked_transcript
        save_processed_transcripts=await saf.process_raw_transcript(raw_transcript_data, yt_id)
        transcript=save_processed_transcripts["transcript"]
        linked_transcript=save_processed_transcripts["linked_transcript"]
        print("Transcript finished")#, transcript)

        # Make vector db
        if vector_embeedding_bool:
            vectordb_and_textchunks=await saf.assembly_generate_vectordb_and_chunks(yt_id, save_processed_transcripts["transcript"])
            text_chunks=vectordb_and_textchunks["text_chunks"]
            print("Text Chunks Finished")# ", text_chunks)

        # Generate summarized segments
        if summary_segments_bool:
            model_responses=await saf.generate_summarized_segments(save_processed_transcripts["transcript"])#,[], 10)
            print("Summarized Chunks Finished")#, model_responses)

        # Make meta summary
        if meta_summary_bool:
            # meta_summary=await saf.generate_meta_summary(model_responses)
            meta_summary=await saf.meta_summary_generator.generate_meta_summary(model_responses)
            print("Meta Summary Finished: ", meta_summary)

            # add the hook to the meta summary
            recap_hook=await saf.generate_recap_hook(meta_summary)
            meta_summary=recap_hook+"\n"+meta_summary+"\n\nDISCLAIMER: This is all AI generated and there are frequent errors."


        # get some video metadata
        if video_metadata_bool:
            async def get_video_metadata(video_id):
                url = 'https://www.youtube.com/watch?v='+video_id
                yt = YouTube(url)

                raw_date=yt.publish_date.__str__()
                date_obj=datetime.datetime.strptime(raw_date, "%Y-%m-%d %H:%M:%S")
                date_str=date_obj.strftime("%m/%d/%Y")

                full_title=yt.title+"\nStream Date: "+date_str

                return full_title
            full_title=await get_video_metadata(yt_id)

        # Save everything
        await saf.save_data(yt_id, save_processed_transcripts)
        if vector_embeedding_bool:
            await saf.save_data(yt_id, {"text_chunks":vectordb_and_textchunks["text_chunks"]})
        if summary_segments_bool:
            await saf.save_data(yt_id, {"summarized_chunks":model_responses})
        if meta_summary_bool:
            await saf.save_data(yt_id, {"meta":meta_summary})
        if video_metadata_bool:
            await saf.save_data(yt_id, {"video_characteristics":{"title":full_title}})

        
        # Setup discord to send message
        new_transcript_model_data=await saf.grab_transcript_data(yt_id)
        if new_transcript_model_data.video_characteristics.get("title", None)!=None:
            full_title=new_transcript_model_data.video_characteristics["title"]
        else:
            full_title=None
        discord_recaps_to_send.append({"meta":new_transcript_model_data.meta,"yt_id":yt_id, "title":full_title})

    
    # Using discord_recaps_to_send to send recaps to discord
    async def send_discord_recaps():
        class MessageSendingClient(discord.Client):
            async def on_ready(self):
                async def send_recap(recap):
                    # Send discord message header
                    destinyrecaps_url="https://destinyrecaps.com"+"/details?video_id="+recap["yt_id"]
                    destinyrecaps_msg="Full transcript and embedding search at "+destinyrecaps_url
                    if recap.get("title",None)!=None:
                        youtube_msg=recap["title"]+": "+"https://www.youtube.com/watch?v="+recap["yt_id"]
                    else:
                        youtube_msg="https://www.youtube.com/watch?v="+recap["yt_id"]

                    header_message=f"{youtube_msg}\n{destinyrecaps_msg}"
                    await channel.send(header_message)

                    # initialize variables for recap message
                    tag_message="@everyone \n"
                    message_str=tag_message+html2text.html2text(recap["meta"])
                    start_index=0
                    recap_chunks={}
                    recap_chunks["start_finish"]=[0]
                    recap_chunks["segments"]=[]
                    increment_size=1500

                    # increment for the number of segments needed
                    for i in range((len(message_str)//increment_size)+1):
                        
                        # find the the reasonable end of the segment
                        finish_index=start_index+increment_size
                        if finish_index>=len(message_str):
                            finish_index=None
                        else:
                            while message_str[finish_index]!="\n":
                                finish_index+=1
                                if (finish_index-start_index)>2100:
                                    print("Didn't find a newline")
                                    break
                                if finish_index>=len(message_str):
                                    finish_index=None
                                    break
                        
                        # append the segments to the list
                        recap_chunks["segments"].append(message_str[start_index:finish_index])
                        start_index=finish_index
                        recap_chunks["start_finish"].append(start_index)

                        if finish_index==None:
                            break

                    print("Sending c-hunks: ",len(recap_chunks["segments"]))
                    for recap_chunk in recap_chunks["segments"]:
                        await channel.send(recap_chunk)


                print(f'Discord logged in as {self.user}')
                channels=self.get_all_channels()
                for channel in channels:
                    print(channel.name)
                    if channel.name=="recaps":
                        if channel:
                            for recap in discord_recaps_to_send:
                                print("Sending Recap")
                                try:
                                    await send_recap(recap)
                                except Exception as e:
                                    # print as much as possible
                                    print("ERROR: ",e)
                                    print(traceback.format_exc())

                await self.close()
                print("Send and client closed")

        intents = discord.Intents.default()
        intents.messages = True 
        client = MessageSendingClient(intents=intents)

        await client.start(keys["discord"])

    # start the discord recaps sending
    try:
        await send_discord_recaps()
    except Exception as e:
        print("ERROR: ",e)
        print(traceback.format_exc())

# %%
async def redo_recap_controller(item_count=3):
    all_transcript_data = await saf.get_all_data()
    if item_count>len(all_transcript_data):
        item_count=len(all_transcript_data)
    print(f"REDOING RECAPS FOR {item_count} ITEMS")
    for i, transcript_model_data in enumerate(all_transcript_data[::-1][:item_count]):
        print(i, transcript_model_data.video_id, transcript_model_data.video_characteristics)

    for i, transcript_model_data in enumerate(all_transcript_data[::-1][:item_count]):
        print("Redoing:",i, transcript_model_data.video_id, transcript_model_data.video_characteristics)
        await redo_recap([transcript_model_data], transcript_model_data.video_id)

# %%
await redo_recap_controller()
# Out:
# REDOING RECAPS FOR 3 ITEMS
# 0 2O8rCcpFswk {'title': "Sneako Gets Punched And BJG Debates A Hostage's Sister\nStream Date: 06/17/2024"}
# 1 3kJr7ODrwNw {'title': "Chillin' idk\nStream Date: 06/19/2024"}
# 2 hAf0iOS-2V4 {'title': "SHE'S ACTUALLY MAD! Brutal Live Debate That Made BJG Storm Off"}
# Redoing: 0 2O8rCcpFswk {'title': "Sneako Gets Punched And BJG Debates A Hostage's Sister\nStream Date: 06/17/2024"}
# REDOING RECAP FOR:  2O8rCcpFswk
# {'text': 'looks', 'start': 186945, 'end': 187361, 'confidence': 0.98049, 'speaker': 'A', 'channel': None}
# 585
# 599
# Destiny starts
# Finished diarization cutoff
# Transcript finished
# Number of chunks:  119
# Finished generating embeddings
# Finished making vector db
# Saved vector db to: destinyapp/vector_dbs/2O8rCcpFswk.index
# Text Chunks Finished
# Approximate cost:  0.083475   Number of segments:  7
# 0 1 2 3 4 5 6
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 await redo_recap_controller()
#
# Cell In[79], line 11, in redo_recap_controller(item_count)
#       9 for i, transcript_model_data in enumerate(all_transcript_data[::-1][:item_count]):
#      10     print("Redoing:",i, transcript_model_data.video_id, transcript_model_data.video_characteristics)
# ---> 11     await redo_recap([transcript_model_data], transcript_model_data.video_id)
#
# Cell In[67], line 24, in redo_recap(transcript_model_datas, vector_embeedding_bool, summary_segments_bool, meta_summary_bool, video_metadata_bool)
#      22 # Generate summarized segments
#      23 if summary_segments_bool:
# ---> 24     model_responses=await saf.generate_summarized_segments(save_processed_transcripts["transcript"])#,[], 10)
#      25     print("Summarized Chunks Finished")#, model_responses)
#      27 # Make meta summary
#
# File d:\DestinyFolder\DestinyRecaps\DestinyRecapsApi\serverproject\destinyapp\api\ServerAiFunctions.py:513, in generate_summarized_segments(transcript, segments, increment_chars, prompt_info)
#     510     return [bot_response,index]
#     512 # Run segmention process
# --> 513 summary_responses=await asyncio.gather(*(fetch_response(in_data) for in_data in model_responses))
#     515 # setup data to feed into model
#     516 for i in range(len(summary_responses)):
#
# File d:\DestinyFolder\DestinyRecaps\DestinyRecapsApi\serverproject\destinyapp\api\ServerAiFunctions.py:498, in generate_summarized_segments.<locals>.fetch_response(input_data)
#     496 print(str(index)+" ", end="")
#     497 try:
# --> 498     bot_response=await async_response_handler(
#     499         prompt=conv_messages,
#     500         modelcompany=model_company,
#     501         modelname=model_name,
#     502     )
#     503     break
#     504 except Exception as e:
#
# File d:\DestinyFolder\DestinyRecaps\DestinyRecapsApi\serverproject\destinyapp\api\ServerAiFunctions.py:84, in async_response_handler(prompt, modelcompany, modelname, temp, frequency_penalty, presence_penalty)
#      82 elif modelcompany==ModelCompanyEnum.anthropic:
#      83     system_message=prompt[0]["content"]
# ---> 84     response = await views.async_anthropic_client.messages.create(
#      85             model=modelname,
#      86             max_tokens=4000,
#      87             temperature=temp,
#      88             system=system_message,
#      89             messages=prompt[1:]
#      90         )
#      91     return response.content[0].text
#      93 else:
#
# File d:\DestinyFolder\env\Lib\site-packages\anthropic\resources\messages.py:1474, in AsyncMessages.create(self, max_tokens, messages, model, metadata, stop_sequences, stream, system, temperature, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#    1443 @required_args(["max_tokens", "messages", "model"], ["max_tokens", "messages", "model", "stream"])
#    1444 async def create(
#    1445     self,
#    (...)
#    1472     timeout: float | httpx.Timeout | None | NotGiven = 600,
#    1473 ) -> Message | AsyncStream[MessageStreamEvent]:
# -> 1474     return await self._post(
#    1475         "/v1/messages",
#    1476         body=await async_maybe_transform(
#    1477             {
#    1478                 "max_tokens": max_tokens,
#    1479                 "messages": messages,
#    1480                 "model": model,
#    1481                 "metadata": metadata,
#    1482                 "stop_sequences": stop_sequences,
#    1483                 "stream": stream,
#    1484                 "system": system,
#    1485                 "temperature": temperature,
#    1486                 "top_k": top_k,
#    1487                 "top_p": top_p,
#    1488             },
#    1489             message_create_params.MessageCreateParams,
#    1490         ),
#    1491         options=make_request_options(
#    1492             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1493         ),
#    1494         cast_to=Message,
#    1495         stream=stream or False,
#    1496         stream_cls=AsyncStream[MessageStreamEvent],
#    1497     )
#
# File d:\DestinyFolder\env\Lib\site-packages\anthropic\_base_client.py:1738, in AsyncAPIClient.post(self, path, cast_to, body, files, options, stream, stream_cls)
#    1724 async def post(
#    1725     self,
#    1726     path: str,
#    (...)
#    1733     stream_cls: type[_AsyncStreamT] | None = None,
#    1734 ) -> ResponseT | _AsyncStreamT:
#    1735     opts = FinalRequestOptions.construct(
#    1736         method="post", url=path, json_data=body, files=await async_to_httpx_files(files), **options
#    1737     )
# -> 1738     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#
# File d:\DestinyFolder\env\Lib\site-packages\anthropic\_base_client.py:1441, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls, remaining_retries)
#    1432 async def request(
#    1433     self,
#    1434     cast_to: Type[ResponseT],
#    (...)
#    1439     remaining_retries: Optional[int] = None,
#    1440 ) -> ResponseT | _AsyncStreamT:
# -> 1441     return await self._request(
#    1442         cast_to=cast_to,
#    1443         options=options,
#    1444         stream=stream,
#    1445         stream_cls=stream_cls,
#    1446         remaining_retries=remaining_retries,
#    1447     )
#
# File d:\DestinyFolder\env\Lib\site-packages\anthropic\_base_client.py:1470, in AsyncAPIClient._request(self, cast_to, options, stream, stream_cls, remaining_retries)
#    1467     kwargs["auth"] = self.custom_auth
#    1469 try:
# -> 1470     response = await self._client.send(
#    1471         request,
#    1472         stream=stream or self._should_stream_response_body(request=request),
#    1473         **kwargs,
#    1474     )
#    1475 except httpx.TimeoutException as err:
#    1476     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File d:\DestinyFolder\env\Lib\site-packages\httpx\_client.py:1661, in AsyncClient.send(self, request, stream, auth, follow_redirects)
#    1653 follow_redirects = (
#    1654     self.follow_redirects
#    1655     if isinstance(follow_redirects, UseClientDefault)
#    1656     else follow_redirects
#    1657 )
#    1659 auth = self._build_request_auth(request, auth)
# -> 1661 response = await self._send_handling_auth(
#    1662     request,
#    1663     auth=auth,
#    1664     follow_redirects=follow_redirects,
#    1665     history=[],
#    1666 )
#    1667 try:
#    1668     if not stream:
#
# File d:\DestinyFolder\env\Lib\site-packages\httpx\_client.py:1689, in AsyncClient._send_handling_auth(self, request, auth, follow_redirects, history)
#    1686 request = await auth_flow.__anext__()
#    1688 while True:
# -> 1689     response = await self._send_handling_redirects(
#    1690         request,
#    1691         follow_redirects=follow_redirects,
#    1692         history=history,
#    1693     )
#    1694     try:
#    1695         try:
#
# File d:\DestinyFolder\env\Lib\site-packages\httpx\_client.py:1726, in AsyncClient._send_handling_redirects(self, request, follow_redirects, history)
#    1723 for hook in self._event_hooks["request"]:
#    1724     await hook(request)
# -> 1726 response = await self._send_single_request(request)
#    1727 try:
#    1728     for hook in self._event_hooks["response"]:
#
# File d:\DestinyFolder\env\Lib\site-packages\httpx\_client.py:1763, in AsyncClient._send_single_request(self, request)
#    1758     raise RuntimeError(
#    1759         "Attempted to send an sync request with an AsyncClient instance."
#    1760     )
#    1762 with request_context(request=request):
# -> 1763     response = await transport.handle_async_request(request)
#    1765 assert isinstance(response.stream, AsyncByteStream)
#    1766 response.request = request
#
# File d:\DestinyFolder\env\Lib\site-packages\httpx\_transports\default.py:373, in AsyncHTTPTransport.handle_async_request(self, request)
#     360 req = httpcore.Request(
#     361     method=request.method,
#     362     url=httpcore.URL(
#    (...)
#     370     extensions=request.extensions,
#     371 )
#     372 with map_httpcore_exceptions():
# --> 373     resp = await self._pool.handle_async_request(req)
#     375 assert isinstance(resp.stream, typing.AsyncIterable)
#     377 return Response(
#     378     status_code=resp.status,
#     379     headers=resp.headers,
#     380     stream=AsyncResponseStream(resp.stream),
#     381     extensions=resp.extensions,
#     382 )
#
# File d:\DestinyFolder\env\Lib\site-packages\httpcore\_async\connection_pool.py:216, in AsyncConnectionPool.handle_async_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     await self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, AsyncIterable)
#
# File d:\DestinyFolder\env\Lib\site-packages\httpcore\_async\connection_pool.py:196, in AsyncConnectionPool.handle_async_request(self, request)
#     192 connection = await pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = await connection.handle_async_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File d:\DestinyFolder\env\Lib\site-packages\httpcore\_async\connection.py:101, in AsyncHTTPConnection.handle_async_request(self, request)
#      98     self._connect_failed = True
#      99     raise exc
# --> 101 return await self._connection.handle_async_request(request)
#
# File d:\DestinyFolder\env\Lib\site-packages\httpcore\_async\http11.py:143, in AsyncHTTP11Connection.handle_async_request(self, request)
#     141     async with Trace("response_closed", logger, request) as trace:
#     142         await self._response_closed()
# --> 143 raise exc
#
# File d:\DestinyFolder\env\Lib\site-packages\httpcore\_async\http11.py:113, in AsyncHTTP11Connection.handle_async_request(self, request)
#     102     pass
#     104 async with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = await self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#     121 network_stream = self._network_stream
#
# File d:\DestinyFolder\env\Lib\site-packages\httpcore\_async\http11.py:186, in AsyncHTTP11Connection._receive_response_headers(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = await self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#     188         break
#
# File d:\DestinyFolder\env\Lib\site-packages\httpcore\_async\http11.py:224, in AsyncHTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = await self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File d:\DestinyFolder\env\Lib\site-packages\httpcore\_backends\anyio.py:34, in AnyIOStream.read(self, max_bytes, timeout)
#      32 with anyio.fail_after(timeout):
#      33     try:
# ---> 34         return await self._stream.receive(max_bytes=max_bytes)
#      35     except anyio.EndOfStream:  # pragma: nocover
#      36         return b""
#
# File d:\DestinyFolder\env\Lib\site-packages\anyio\streams\tls.py:205, in TLSStream.receive(self, max_bytes)
#     204 async def receive(self, max_bytes: int = 65536) -> bytes:
# --> 205     data = await self._call_sslobject_method(self._ssl_object.read, max_bytes)
#     206     if not data:
#     207         raise EndOfStream
#
# File d:\DestinyFolder\env\Lib\site-packages\anyio\streams\tls.py:147, in TLSStream._call_sslobject_method(self, func, *args)
#     144     if self._write_bio.pending:
#     145         await self.transport_stream.send(self._write_bio.read())
# --> 147     data = await self.transport_stream.receive()
#     148 except EndOfStream:
#     149     self._read_bio.write_eof()
#
# File d:\DestinyFolder\env\Lib\site-packages\anyio\_backends\_asyncio.py:1133, in SocketStream.receive(self, max_bytes)
#    1128 if (
#    1129     not self._protocol.read_event.is_set()
#    1130     and not self._transport.is_closing()
#    1131 ):
#    1132     self._transport.resume_reading()
# -> 1133     await self._protocol.read_event.wait()
#    1134     self._transport.pause_reading()
#    1136 try:
#
# File C:\Python311\Lib\asyncio\locks.py:213, in Event.wait(self)
#     211 self._waiters.append(fut)
#     212 try:
# --> 213     await fut
#     214     return True
#     215 finally:
#
# CancelledError:

# %%
for i, transcript_model_data in enumerate(all_transcript_data[::-1]):
    if i==3:
        print(i, transcript_model_data.video_id, transcript_model_data.video_characteristics)
        await redo_recap([transcript_model_data], transcript_model_data.video_id)
        break
# Out:
# 3 F6B8n7Jg7Zo {'title': 'This SpaceX Engineer is Building a Mobile Nuclear Reactor | Doug Bernauer'}
# REDOING RECAP FOR:  F6B8n7Jg7Zo
# {'text': 'looks', 'start': 186955, 'end': 187331, 'confidence': 7.28161, 'speaker': 'A', 'channel': None}
# 587
# 588
# Destiny doesn't start
# Finished diarization cutoff
# Transcript finished
# Number of chunks:  77
# Finished generating embeddings
# Finished making vector db
# Saved vector db to: destinyapp/vector_dbs/F6B8n7Jg7Zo.index
# Text Chunks Finished
# Approximate cost:  0.050586   Number of segments:  4
# 0 1 2 3 0 0
# 1 1
# 2 2
# 3 3
# Summarized Chunks Finished
# Expected cost:  0.004275
# Meta Summary Finished:  Here's a comprehensive summary of the main topics and smaller details discussed in the collection of summaries:
#
# <h2>Main Topics</h2>
#
# <h3>1. SpaceX Experience</h3>
# <ul>
#   <li>Worked at SpaceX for 12 years, joining when the company had no successful launches</li>
#   <li>Present for the fourth Falcon 1 launch, which was successful</li>
#   <li>Worked on various projects including ground support equipment for Falcon 9, Grasshopper rocket, F9R Dev, Hyperloop, and Boring Company</li>
#   <li>Often worked 100-hour weeks without being asked</li>
# </ul>
#
# <h3>2. Radiant - Current Venture</h3>
# <ul>
#   <li>Founder of Radiant, designing portable nuclear microreactors</li>
#   <li>Aims for mass production and deployment worldwide</li>
#   <li>Inspired by Department of Defense's Pele program for portable nuclear reactors</li>
#   <li>Sees dual-use opportunity for military and space applications</li>
# </ul>
#
# <h3>3. Nuclear Technology Challenges and Opportunities</h3>
# <ul>
#   <li>Complexities of nuclear reactor physics</li>
#   <li>Regulatory challenges in the industry</li>
#   <li>Lack of technological advancements compared to aerospace and software industries</li>
#   <li>Emphasis on cost reduction and cost-benefit analysis</li>
#   <li>Need for regulatory reform to foster innovation</li>
# </ul>
#
# <h3>4. Motivation and Philosophy</h3>
# <ul>
#   <li>Desire to work on important projects with lasting impact</li>
#   <li>View of engineering as an art rather than a science</li>
#   <li>Emphasis on creating net value for society</li>
#   <li>Importance of mission alignment in career decisions</li>
# </ul>
#
# <h2>Smaller Details</h2>
#
# <ul>
#   <li><b>Mars Colonization:</b> Realization that solar power alone wouldn't be sufficient, necessitating nuclear power</li>
#   <li><b>Benefits of Nuclear Technology:</b> Life-saving potential in military applications, importance in medical imaging and isotopes</li>
#   <li><b>Organizational Challenges:</b> Scaling the organization and managing people more challenging than technical aspects</li>
#   <li><b>Importance of Storytelling:</b> Crucial for gaining support from federal nuclear institutions</li>
#   <li><b>Team Building:</b> Preference for a core team of experienced individuals leading newer team members</li>
#   <li><b>Future Innovation Areas:</b> Interest in mining and farming as potential areas for innovation</li>
#   <li><b>Other Nuclear Companies:</b> Mentions of Kairos, TerraPower, and fusion energy projects</li>
#   <li><b>Problem-Solving Approach:</b> Described as creative and academic, viewing self as a simplifier</li>
#   <li><b>Societal Issues:</b> Discussion on outdated regulations and need for thoughtful rulemaking</li>
#   <li><b>Customer Focus:</b> Emphasis on delivering value to customers and protecting their interests, especially in remote areas</li>
# </ul>
# updating transcript data
# updating transcript data
# updating transcript data
# updating transcript data
# updating transcript data
# Discord logged in as DestinySummarizer#3997
# Text Channels
# Voice Channels
# general
# General
# archive
# recaps
# Sending Recap
# Sending chunks:  2
# rules
# test
# Send and client closed

# %%
for t_d_i in all_transcript_data:
    print(t_d_i.video_characteristics)
# Out:
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'title': 'This SpaceX Engineer is Building a Mobile Nuclear Reactor | Doug Bernauer'}
# {'title': "SHE'S ACTUALLY MAD! Brutal Live Debate That Made BJG Storm Off"}
# {'title': "Chillin' idk"}
# {'title': "Sneako Gets Punched And BJG Debates A Hostage's Sister\nStream Date: 06/17/2024"}

# %%
print(len(all_transcript_data))
# Out:
# 19
